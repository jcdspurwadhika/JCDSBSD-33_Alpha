# %% [markdown]
# <img src="https://s3-us-west-2.amazonaws.com/public.notion-static.com/7fa59d58-ba42-4de1-840a-e2e31ab9ce3b/ba416d9e-ee4d-4b7a-a9fe-a506333af2b7.png" alt="Abstract Banner" width="100%" height="200" style="object-fit: cover; border-radius: 8px;">
#
# by: Elmar Leonard, Muhammad Rafi Andrianto and Valencia

# %% [markdown]
# # **Section 0: Project Initialization**

# %% [markdown]
# ## **0.1 Importing Library**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from imblearn.pipeline import Pipeline as ImbPipeline
from imblearn.over_sampling import SMOTE
from imblearn.combine import SMOTEENN, SMOTETomek

from sklearn.model_selection import cross_validate, GridSearchCV, learning_curve

from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

from sklearn.model_selection import TimeSeriesSplit, RandomizedSearchCV

from sklearn.preprocessing import FunctionTransformer, RobustScaler, OneHotEncoder
from category_encoders import BinaryEncoder

from sklearn.impute import SimpleImputer
from sklearn.feature_selection import SelectKBest, f_classif

from sklearn.linear_model import LogisticRegression, RidgeClassifier, SGDClassifier
from sklearn.svm import LinearSVC, SVC

from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier, ExtraTreesClassifier, BaggingClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, precision_recall_curve

from sklearn.calibration import CalibratedClassifierCV
from sklearn.frozen import FrozenEstimator
from sklearn.metrics import average_precision_score

import pickle
import shap
import copy
import os
import sys

sys.path.append(os.path.abspath("..")) 

from Utils.serving_utils import (
    build_seller_lookup, save_seller_lookup, load_seller_lookup, refresh_seller_lookup,
    attach_seller_late_rate_frozen, calculate_haversine, convert_bool_to_int,
    get_black_friday_date, is_black_friday_or_holiday,
    aggregate_order_features, OrderFeatureAggregator,
    ServingModel, load_serving_model,
)

pd.set_option('display.max_columns', None)

# %% [markdown]
# ## **0.2 Global Configuration**

# %%
DATA_DIR = 'Dataset' 
timestamp_columns = ['order_purchase_timestamp', 'order_approved_at', 'order_delivered_carrier_date', 'order_delivered_customer_date', 'order_estimated_delivery_date', 'shipping_limit_date']

RANDOM_STATE = 42

df = pd.read_csv(f'../{DATA_DIR}/Cleaned Data/cleaned.csv', parse_dates=timestamp_columns)
delivered = df[df["order_status"]=="delivered"]

pd.set_option('display.max_columns', None)
print(f"Dataframe size: {df.shape}")
print(f"Delivered Dataframe size: {delivered.shape}")
# Out:
# Dataframe size: (111777, 39)
# Delivered Dataframe size: (108566, 39)

# %% [markdown]
# # **Section 1: Dataset Preparation**

# %% [markdown]
# ## **1.1 splitting the data**

# %% [markdown]
# Prior to splitting the dataset, it is necessary to establish the target variable. Because the objective is to predict delivery punctuality, a boolean column was created to clearly flag whether or not each order is late.

# %%
delivered['is_late'] = (
    delivered['order_delivered_customer_date'].dt.normalize() >
    delivered['order_estimated_delivery_date'].dt.normalize()
)

# %% [markdown]
# The dataset was partitioned into training, validation, and testing sets using a 60/20/20 ratio. To preserve the chronological integrity of the historical data, a time-based split was utilized instead of randomized sample selection.

# %%
order_purchase = delivered.groupby('order_id')['order_purchase_timestamp'].transform('first')
cutoff = order_purchase.quantile(0.8)
print('Test split cutoff:', cutoff)

full_train_items = delivered[order_purchase < cutoff].copy()
test_items = delivered[order_purchase >= cutoff].copy()

order_purchase = full_train_items.groupby('order_id')['order_purchase_timestamp'].transform('first')
cutoff = order_purchase.quantile(0.75)
print('Validation split cutoff:', cutoff)

validation_items = full_train_items[order_purchase >= cutoff].copy()
train_items = full_train_items[order_purchase < cutoff].copy()
print('train orders:', train_items['order_id'].nunique(), '| validation orders:', validation_items['order_id'].nunique(), '| test orders:', test_items['order_id'].nunique())
# Out:
# Test split cutoff: 2018-05-22 01:07:35
# Validation split cutoff: 2018-02-28 19:57:12
# train orders: 57093 | validation orders: 18867 | test orders: 19110

# %% [markdown]
# **Splitting the data by purchase-date quantiles** (rather than using a randomized train-test split) **is the correct approach** for this use case. Delivery logistics, seller behavior, and shipping infrastructure naturally drift over time. Consequently, evaluating the model on randomly shuffled historical data would artificially inflate performance metrics, failing to reflect how the model will perform in production when processing future, unseen data.

# %% [markdown]
# ## **1.2 creating lookup table based on the late delivery**

# %% [markdown]
# **A lookup table will be generated** to calculate historical seller lateness rates from prior order data. **This feature engineering step** incorporates additive smoothing (
# 𝐾𝑠𝑚𝑜𝑜𝑡ℎ=10) to stabilize predictions for low-volume merchants, preventing sellers with only one or two shipments from being skewed to extreme 0% or 100% rates. Furthermore, assigning the global lateness rate to a seller's first shipment serves as a robust, low-overhead validation that the time window is not peeking into the future.

# %%
K_SMOOTH = 10

full_train_items = full_train_items.sort_values(['seller_id', 'order_purchase_timestamp'])
full_train_items['seller_late_item'] = (
    full_train_items['shipping_limit_date'] < full_train_items['order_delivered_carrier_date']
).astype(int)

GLOBAL_LATE_RATE = full_train_items['seller_late_item'].mean()
print('global seller late-to-carrier rate (train):', round(GLOBAL_LATE_RATE, 4))

g = full_train_items.groupby('seller_id')['seller_late_item']
prior_count = g.cumcount()                                  
prior_late = g.cumsum() - full_train_items['seller_late_item'] 

full_train_items['seller_late_rate'] = (
    (prior_late + K_SMOOTH * GLOBAL_LATE_RATE) / (prior_count + K_SMOOTH)
)

first_shipment = full_train_items.groupby('seller_id').head(1)
assert np.allclose(first_shipment['seller_late_rate'], GLOBAL_LATE_RATE), 'expanding window leaked!'
print('expanding-window check passed: first shipment per seller == global rate')
# Out:
# global seller late-to-carrier rate (train): 0.0964
# expanding-window check passed: first shipment per seller == global rate

# %%
seller_lookup = (
    full_train_items.groupby('seller_id')['seller_late_item']
    .agg(total_shipments='count', late_shipments='sum')
)
seller_lookup['seller_late_rate'] = (
    (seller_lookup['late_shipments'] + K_SMOOTH * GLOBAL_LATE_RATE)
    / (seller_lookup['total_shipments'] + K_SMOOTH)
)
print(seller_lookup.shape, 'sellers in lookup table')
seller_lookup.head()
# Out:
# (2401, 3) sellers in lookup table
#                                   total_shipments  late_shipments  \
# seller_id
# 0015a82c2db000af6aaaf3ae2ecb0532                3               0
# 001cca7ae9ae17fb1caed9dfb1094831              231              12
# 002100f778ceb8431b7a1020ff7ab48f               54               5
# 003554e2dce176b5555353e4f3555ac8                1               0
# 004c9cd9d87a3c30c522c48c4fc07416              167               0
#
#                                   seller_late_rate
# seller_id
# 0015a82c2db000af6aaaf3ae2ecb0532          0.074123
# 001cca7ae9ae17fb1caed9dfb1094831          0.053791
# 002100f778ceb8431b7a1020ff7ab48f          0.093181
# 003554e2dce176b5555353e4f3555ac8          0.087599
# 004c9cd9d87a3c30c522c48c4fc07416          0.005444

# %% [markdown]
# **Sellers not present in the lookup table will be assigned the global lateness rate.** To validate this logic, the process will be evaluated against a sample dataset to quantify the volume of unseen sellers successfully imputed with the global baseline.

# %%
example = attach_seller_late_rate_frozen(test_items, seller_lookup, GLOBAL_LATE_RATE)
n_unseen = example['seller_id'].isin(seller_lookup.index).eq(False).sum()
print(f'test rows from sellers unseen in train: {n_unseen} (fell back to global rate)')
# Out:
# test rows from sellers unseen in train: 2964 (fell back to global rate)

# %% [markdown]
# ## 1.3 to make the data as valid as possible

# %% [markdown]
# **Prior to constructing the model pipeline, the training data must be aligned** to match the exact schema and state of a real-time, incoming order. To achieve this environmental parity, we will subset the data to retain only the features available at the moment of order submission, transforming the dataset into the following structure:
# | Column | Type | Description |
# | --- | --- | --- |
# | order_id | string | Unique identifier of the order (an order can have multiple items) |
# | order_purchase_timestamp | datetime (string) | Timestamp when the order was placed. |
# | product_id | string | Unique identifier of the product. |
# | product_weight_g | float | Product weight in grams. |
# | product_length_cm | float | Product length in cm. |
# | product_height_cm | float | Product height in cm. |
# | product_width_cm | float | Product width in cm. |
# | seller_id | string | Unique identifier of the seller. |
# | seller_zip_code_prefix | integer | First 5 digits of seller's zip code. |
# | seller_geo_lat | float | Latitude of the seller zip code location. |
# | seller_geo_lng | float | Longitude of the seller zip code location. |
# | seller_city | string | Seller's city. |
# | seller_state | string | Seller's state. |
# | product_category_name_english | string | Same category translated to English. |
# | customer_unique_id | string | The actual unique person (use this to track customers across multiple orders) |
# | customer_zip_code_prefix | integer | First 5 digits of customer's zip code. |
# | customer_geo_lat | float | Latitude of the customer zip code location. |
# | customer_geo_lng | float | Longitude of the customer zip code location. |
# | customer_city | string | Customer's city. |
# | customer_state | string | Customer's state (Brazilian state code, e.g. SP, RJ). |
# | order_estimated_delivery_date | datetime (string) | Delivery date estimate given to the customer at purchase time. |
# | price | float | Item price. |
# | freight_value | float | Freight/shipping cost for this item. (if an order has more than one item the freight value is splitted between items) |
# | payment_sequential | integer | Sequence number if a customer used more than one payment method for the same order. |
# | payment_type | string | Payment method (credit_card, boleto, voucher, debit_card). |
# | n_vouchers | int | Total voucher used in that order |
# | total_payment_value | float | Total payment paid for the order |
# | payment_installments | integer | Number of installments chosen. |
# | payment_value | float | Amount paid via this payment row. |
#
# **Consequently, features that introduce data leakage will be dropped**, as they utilize information that would be unavailable at the time of inference in production.

# %%
DROP_COLUMNS =  ["customer_id", "order_status", "order_approved_at", "order_delivered_carrier_date", 
                 "order_delivered_customer_date", "order_item_id", "shipping_limit_date",
                 "review_score", "review_comment_message", "review_creation_date", "review_answer_timestamp"]

print('shape of train data before:', train_items.shape, ' | shape of test data before:', test_items.shape, ' | shape of validation data before:', validation_items.shape)

train_items.drop(columns=DROP_COLUMNS, inplace=True)
test_items.drop(columns=DROP_COLUMNS, inplace=True)
validation_items.drop(columns=DROP_COLUMNS, inplace=True)

print('shape of train data after:', train_items.shape, '  | shape of test data after:', test_items.shape, '  | shape of validation data after:', validation_items.shape)
# Out:
# shape of train data before: (65139, 40)  | shape of test data before: (21714, 40)  | shape of validation data before: (21713, 40)
# shape of train data after: (65139, 29)   | shape of test data after: (21714, 29)   | shape of validation data after: (21713, 29)

# %% [markdown]
# ## **1.4 Feature engineering**

# %% [markdown]
# **Prior to training the model, the dataset will be enriched with additional features** to improve predictive performance. The engineered features include the following:

# %% [markdown]
# ### **1.4.1 Volume of the product**

# %% [markdown]
# **Product volume will be calculated as a composite feature** by combining the individual length, width, and height dimensions. This engineered feature consolidates dimensional attributes into a single, highly predictive signal for the model.

# %%
feat = delivered.copy()
feat['item_volume_cm3'] = (feat['product_length_cm'] * feat['product_height_cm'] * feat['product_width_cm'])

feat.loc[:, ["order_id", "item_volume_cm3"]].head()
# Out:
#                            order_id  item_volume_cm3
# 0  e481f51cbdc54678b7cc49136f2d6af7           1976.0
# 1  53cdb2fc8bc7dce0b6741e2150273451           4693.0
# 2  47770eb9100c2d0c44946d9cf07ec65d           9576.0
# 3  949d5b44dbf5de918fe9c16f97b45f8a           6000.0
# 4  ad21c59c0840e6cb83a9ceb5573f8159          11475.0

# %% [markdown]
# ### **1.4.2 Delivery Distance from Seller to Customer**

# %% [markdown]
# **The Haversine formula will be utilized to calculate the geospatial distance** between sellers and customers, using the centroid latitude and longitude coordinates derived from their respective zip codes. This continuous distance feature will then be binned into categorical labels ranging from short-range to long-haul shipments.

# %%
feat["delivery_distance_km"] = calculate_haversine(feat["seller_lng"], feat["seller_lat"], feat["customer_lng"], feat["customer_lat"])

bins = [-1, 50, 300, 1000, 7000]
labels = ['Short-Range (<50km)', 'Regional (50-300km)', 'Interregional (300-1000km)', 'Long-Haul (>1000km)']

feat['distance_group'] = pd.cut(feat['delivery_distance_km'], bins=bins, labels=labels)

feat.loc[:, ["order_id", "distance_group"]].head()
# Out:
#                            order_id              distance_group
# 0  e481f51cbdc54678b7cc49136f2d6af7         Short-Range (<50km)
# 1  53cdb2fc8bc7dce0b6741e2150273451  Interregional (300-1000km)
# 2  47770eb9100c2d0c44946d9cf07ec65d  Interregional (300-1000km)
# 3  949d5b44dbf5de918fe9c16f97b45f8a         Long-Haul (>1000km)
# 4  ad21c59c0840e6cb83a9ceb5573f8159         Short-Range (<50km)

# %% [markdown]
# ### **1.4.3 Splitted Timestamp**

# %% [markdown]
# **Temporal features will be extracted from the order approval timestamp**, specifically isolating the day, month, and hour of approval. Finally, a promised_days column will be engineered to calculate the total duration allocated between the order creation and the promised delivery date.

# %%
feat['purchase_dow'] = feat['order_approved_at'].dt.day_name()
feat['purchase_month'] = feat['order_approved_at'].dt.month_name()
feat['purchase_hour'] = feat['order_approved_at'].dt.hour
feat['promised_days'] = (feat['order_estimated_delivery_date'] - feat['order_approved_at']).dt.days

feat.loc[:, ["order_id", 'purchase_dow', "purchase_month", 'purchase_hour', 'promised_days']].head()
# Out:
#                            order_id purchase_dow purchase_month  \
# 0  e481f51cbdc54678b7cc49136f2d6af7       Monday        October
# 1  53cdb2fc8bc7dce0b6741e2150273451     Thursday           July
# 2  47770eb9100c2d0c44946d9cf07ec65d    Wednesday         August
# 3  949d5b44dbf5de918fe9c16f97b45f8a     Saturday       November
# 4  ad21c59c0840e6cb83a9ceb5573f8159      Tuesday       February
#
#    purchase_hour  promised_days
# 0             11             15
# 1              3             17
# 2              8             26
# 3             19             26
# 4             22             12

# %% [markdown]
# ### **1.4.4 black friday or holiday or not**

# %% [markdown]
# **A binary holiday indicator will be created** to flag whether an order was placed during peak seasonal events, specifically targeting Black Friday and the December holiday shopping window.

# %%
feat['is_black_friday_or_holiday'] = feat['order_purchase_timestamp'].apply(is_black_friday_or_holiday)

feat.loc[:, ["order_id", 'is_black_friday_or_holiday']].head()
# Out:
#                            order_id  is_black_friday_or_holiday
# 0  e481f51cbdc54678b7cc49136f2d6af7                       False
# 1  53cdb2fc8bc7dce0b6741e2150273451                       False
# 2  47770eb9100c2d0c44946d9cf07ec65d                       False
# 3  949d5b44dbf5de918fe9c16f97b45f8a                       False
# 4  ad21c59c0840e6cb83a9ceb5573f8159                       False

# %% [markdown]
# ### **1.4.5 dominant order**

# %% [markdown]
# **Because the source data is structured at a multi-item level, new attributes will be engineered** to identify the primary seller, primary customer, and dominant product category for each unique order transaction. This step is critical to successfully aggregating the dataset from an item-level to a unified order-level format during downstream processing.

# %%
feat = attach_seller_late_rate_frozen(feat, seller_lookup, GLOBAL_LATE_RATE)
dominant = feat.loc[feat.groupby('order_id')['price'].idxmax()].set_index('order_id')

feat['dominant_product_category'] = feat['order_id'].map(dominant['product_category_name_english'])
feat['primary_seller_geo_state'] = feat['order_id'].map(dominant['seller_geo_state'])
feat['primary_seller_late_rate'] = feat['order_id'].map(dominant['seller_late_rate'])

feat.loc[:, ["order_id", 'dominant_product_category', "primary_seller_geo_state", 'primary_seller_late_rate']].head()
# Out:
#                            order_id dominant_product_category  \
# 0  e481f51cbdc54678b7cc49136f2d6af7                housewares
# 1  53cdb2fc8bc7dce0b6741e2150273451                 perfumery
# 2  47770eb9100c2d0c44946d9cf07ec65d                      auto
# 3  949d5b44dbf5de918fe9c16f97b45f8a                  pet_shop
# 4  ad21c59c0840e6cb83a9ceb5573f8159                stationery
#
#   primary_seller_geo_state  primary_seller_late_rate
# 0                       SP                  0.015295
# 1                       MG                  0.026766
# 2                       SP                  0.040754
# 3                       MG                  0.070028
# 4                       SP                  0.038475

# %% [markdown]
# ### **1.4.6 Information of order is interstate or intrastate**

# %% [markdown]
# **An interstate indicator and a state-to-state routing feature will be engineered** to capture regional logistics dynamics. The first feature will flag whether an order crosses state borders, while the second will explicitly map the geographical pipeline from the seller's state to the customer's destination state.

# %%
feat['is_interstate'] = feat['primary_seller_geo_state'] != feat['customer_geo_state']
feat['route'] = feat['primary_seller_geo_state'] + '_to_' + feat['customer_geo_state']

feat.loc[:, ["order_id", 'is_interstate', "route"]].head()
# Out:
#                            order_id  is_interstate     route
# 0  e481f51cbdc54678b7cc49136f2d6af7          False  SP_to_SP
# 1  53cdb2fc8bc7dce0b6741e2150273451           True  MG_to_BA
# 2  47770eb9100c2d0c44946d9cf07ec65d           True  SP_to_GO
# 3  949d5b44dbf5de918fe9c16f97b45f8a           True  MG_to_RN
# 4  ad21c59c0840e6cb83a9ceb5573f8159          False  SP_to_SP

# %% [markdown]
# ### **1.4.7 Aggregating Dataset**

# %% [markdown]
# **Following the item-level feature engineering steps, the dataset will be aggregated** to produce the final, order-level training set for the model. This aggregation process consolidates the multi-item records into a unified structure, ensuring that each row represents a unique order transaction ready for model ingestion.

# %%
out = pd.DataFrame({
    'total_price': feat.groupby('order_id')['price'].sum(),
    'total_freight_value': feat.groupby('order_id')['freight_value'].sum(),
    'total_weight_g': feat.groupby('order_id')['product_weight_g'].sum(),
    'total_volume_cm3': feat.groupby('order_id')['item_volume_cm3'].sum(),
    
    'n_items': feat.groupby('order_id').size(),
    
    'n_distinct_products': feat.groupby('order_id')['product_id'].nunique(),
    'n_distinct_categories': feat.groupby('order_id')['product_category_name_english'].nunique(),
    'n_distinct_sellers': feat.groupby('order_id')['seller_id'].nunique(),
    
    'distance_group': feat.groupby('order_id')['distance_group'].first(),
    
    'product_category': feat.groupby('order_id')['dominant_product_category'].first(),
    'seller_late_rate': feat.groupby('order_id')['primary_seller_late_rate'].first(),
    'order_purchase_timestamp': feat.groupby('order_id')['order_purchase_timestamp'].first(),
    'purchase_dow': feat.groupby('order_id')['purchase_dow'].first(),
    'purchase_month': feat.groupby('order_id')['purchase_month'].first(),
    'purchase_hour': feat.groupby('order_id')['purchase_hour'].first(),
    'promised_days': feat.groupby('order_id')['promised_days'].first(),
    'is_black_friday_or_holiday': feat.groupby('order_id')['is_black_friday_or_holiday'].first(),
    'order_estimated_delivery_date': feat.groupby('order_id')['order_estimated_delivery_date'].first(),
    'is_interstate': feat.groupby('order_id')['is_interstate'].first(),
    'route': feat.groupby('order_id')['route'].first(),
    'seller_geo_state': feat.groupby('order_id')['primary_seller_geo_state'].first(),
    'customer_geo_state': feat.groupby('order_id')['customer_geo_state'].first(),
    'payment_type': feat.groupby('order_id')['payment_type'].first(),
    'payment_installments': feat.groupby('order_id')['payment_installments'].first(),
    'total_payment_value': feat.groupby('order_id')['total_payment_value'].first(),
    'n_vouchers': feat.groupby('order_id')['n_vouchers'].first(),
    'voucher_value': feat.groupby('order_id')['voucher_value'].first(),
})

# %%
out.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 95070 entries, 00010242fe8c5a6d1ba2dd792cb16214 to fffe41c64501cc87c801fd61db3f6244
# Data columns (total 27 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   total_price                    95070 non-null  float64
#  1   total_freight_value            95070 non-null  float64
#  2   total_weight_g                 95070 non-null  float64
#  3   total_volume_cm3               95070 non-null  float64
#  4   n_items                        95070 non-null  int64
#  5   n_distinct_products            95070 non-null  int64
#  6   n_distinct_categories          95070 non-null  int64
#  7   n_distinct_sellers             95070 non-null  int64
#  8   distance_group                 95070 non-null  category
#  9   product_category               93722 non-null  str
#  10  seller_late_rate               95070 non-null  float64
#  11  order_purchase_timestamp       95070 non-null  datetime64[us]
#  12  purchase_dow                   95070 non-null  str
#  13  purchase_month                 95070 non-null  str
#  14  purchase_hour                  95070 non-null  int32
#  15  promised_days                  95070 non-null  int64
#  16  is_black_friday_or_holiday     95070 non-null  bool
#  17  order_estimated_delivery_date  95070 non-null  datetime64[us]
#  18  is_interstate                  95070 non-null  bool
#  19  route                          95070 non-null  str
#  20  seller_geo_state               95070 non-null  str
#  21  customer_geo_state             95070 non-null  str
#  22  payment_type                   95070 non-null  str
#  23  payment_installments           95070 non-null  float64
#  24  total_payment_value            95070 non-null  float64
#  25  n_vouchers                     95070 non-null  float64
#  26  voucher_value                  95070 non-null  float64
# dtypes: bool(2), category(1), datetime64[us](2), float64(9), int32(1), int64(5), str(7)
# memory usage: 25.3 MB

# %% [markdown]
# ## **1.5 Pipeline**

# %% [markdown]
# ### **1.5.1 Feature & Target**

# %% [markdown]
# **Although the data has been partitioned into training, validation, and testing sets, the features and target variables have not yet been isolated.** Consequently, each of the three datasets will be separated into distinct feature arrays (X) and target vectors (y) to prepare them for model training and evaluation.

# %%
def split_xy(df):
    agg = aggregate_order_features(df, seller_lookup, GLOBAL_LATE_RATE)
    y = agg.pop("is_late")
    X = agg
    return X, y

X_train, y_train = split_xy(train_items)
X_val, y_val = split_xy(validation_items)
X_test, y_test = split_xy(test_items)

print("X_train:", X_train.shape, "| y_train:", y_train.shape)
print("X_val:  ", X_val.shape, "| y_val:  ", y_val.shape)
print("X_test: ", X_test.shape, "| y_test: ", y_test.shape)
# Out:
# X_train: (57093, 28) | y_train: (57093,)
# X_val:   (18867, 28) | y_val:   (18867,)
# X_test:  (19110, 28) | y_test:  (19110,)

# %% [markdown]
# ### **1.5.2 Imputing & Encoding**

# %% [markdown]
# **Next, features will be categorized by data type to apply tailored imputation strategies.** Missing value imputation will be strictly confined to features influenced by seller data-entry habits, specifically `total_weight_g`, `total_volume_cm3`, and `product_category`. The remaining features will not be imputed, as they represent mandatory inputs populated automatically by the system; any missing values in those fields would indicate a fatal system error rather than typical data variance.

# %%
DROP_FOR_MODEL = [
    'order_purchase_timestamp', 'order_estimated_delivery_date', 'seller_customer_distance_km'
]

numeric_features = [
    'total_price', 'total_freight_value','n_items', 'n_distinct_products', 
    'n_distinct_categories', 'n_distinct_sellers',
    'seller_late_rate', 'purchase_hour', 
    'promised_days', 'payment_installments', 'total_payment_value',
    'n_vouchers', 'voucher_value',
]

oh_categorical_features = [
    'purchase_dow', 'purchase_month', 'payment_type', 'distance_group'
]

bin_categorical_features = [
    'route', 'seller_geo_state', 'customer_geo_state'
]

imputed_numeric_features = [
    'total_weight_g', 'total_volume_cm3'
]

imputed_categorical_features = ['product_category']

boolean_features = ['is_interstate', "is_black_friday_or_holiday"]

# %%
imputed_numeric_pipeline = Pipeline([
    ('impute', SimpleImputer(strategy='median')),
    ('scale', RobustScaler()),
])

imputed_categorical_pipeline = Pipeline([
    ('impute', SimpleImputer(strategy='constant', fill_value='missing')),
    ('encode', BinaryEncoder(handle_unknown='value')),
])

numeric_pipeline = Pipeline([
    ('scale', RobustScaler()),
])

oh_categorical_pipeline = Pipeline([
    ('encode', OneHotEncoder(handle_unknown='ignore', min_frequency=0.01, sparse_output=False)),
])

bin_categorical_pipeline = Pipeline([
    ('encode', BinaryEncoder(handle_unknown='value')),
])

boolean_pipeline = Pipeline([
    ('transform', FunctionTransformer(convert_bool_to_int, validate=False, feature_names_out='one-to-one'))
])

preprocessor = ColumnTransformer([
    ('im_num', imputed_numeric_pipeline, imputed_numeric_features),
    ('im_cat', imputed_categorical_pipeline, imputed_categorical_features),
    ('num', numeric_pipeline, numeric_features),
    ('oh_cat', oh_categorical_pipeline, oh_categorical_features),
    ('bin_cat', bin_categorical_pipeline, bin_categorical_features),
    ('bool', boolean_pipeline, boolean_features),
], remainder='drop')

# %% [markdown]
# ### **1.5.3 Full Pipeline**

# %%
pipeline = ImbPipeline([
    ('feature_fix', 'passthrough'),
    ('preprocessor', preprocessor),
    ('select', 'passthrough'),
    ('smote', SMOTE(random_state=RANDOM_STATE)),
    ('classifier', LogisticRegression(class_weight='balanced', max_iter=1000, random_state=RANDOM_STATE)),
])

pipeline
# Out:
# /Users/rafiandrianto/Desktop/Purwadhika/.venv/lib/python3.12/site-packages/sklearn/externals/_numpydoc/docscrape.py:420: UserWarning: Unknown section Example
#   self[section] = content
# Pipeline(steps=[('feature_fix', 'passthrough'),
#                 ('preprocessor',
#                  ColumnTransformer(transformers=[('im_num',
#                                                   Pipeline(steps=[('impute',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scale',
#                                                                    RobustScaler())]),
#                                                   ['total_weight_g',
#                                                    'total_volume_cm3']),
#                                                  ('im_cat',
#                                                   Pipeline(steps=[('impute',
#                                                                    SimpleImputer(fill_value='missing',
#                                                                                  strategy='constant')),
#                                                                   ('encode',
#                                                                    BinaryEncoder())]...
#                                                    'customer_geo_state']),
#                                                  ('bool',
#                                                   Pipeline(steps=[('transform',
#                                                                    FunctionTransformer(feature_names_out='one-to-one',
#                                                                                        func=<function convert_bool_to_int at 0x11fe47c40>))]),
#                                                   ['is_interstate',
#                                                    'is_black_friday_or_holiday'])])),
#                 ('select', 'passthrough'), ('smote', SMOTE(random_state=42)),
#                 ('classifier',
#                  LogisticRegression(class_weight='balanced', max_iter=1000,
#                                     random_state=42))])

# %% [markdown]
# # **Section 2: Model Benchmarking**

# %%
def benchmark_models(pipeline, list_model, x_train, y_train,
                     scoring="roc_auc", cv=5, random_state=None, select="passthrough"):

    all_cv_result = []

    tscv = TimeSeriesSplit(n_splits=cv)

    primary_metric = scoring if isinstance(scoring, str) else list(scoring)[0]

    diagnostic_scoring = {
        "precision": "precision",
        "recall": "recall",
        "f1": "f1",
        "roc_auc": "roc_auc",
        "pr_auc": "average_precision"
    }

    full_scoring = {primary_metric: primary_metric}
    full_scoring.update(diagnostic_scoring)

    for name, model in list_model.items():
        classifier = pipeline.set_params(classifier=model, select=select)
        cv_result = cross_validate(
            estimator=classifier,
            X=x_train, y=y_train,
            cv=tscv,
            scoring=full_scoring,
            return_train_score=True
        )

        row = {
            "Model": name,
            "Mean Train Score": np.mean(cv_result[f"train_{primary_metric}"]),
            "Std Train Score": np.std(cv_result[f"train_{primary_metric}"]),
            "Mean Test Score": np.mean(cv_result[f"test_{primary_metric}"]),
            "Std Test Score": np.std(cv_result[f"test_{primary_metric}"]),
            "Precision": np.mean(cv_result["test_precision"]),
            "Recall": np.mean(cv_result["test_recall"]),
            "F1-Score": np.mean(cv_result["test_f1"]),
            "ROC-AUC": np.mean(cv_result["test_roc_auc"]),
            "PR-AUC": np.mean(cv_result["test_pr_auc"]),
            "Fit Time (s)": np.mean(cv_result["fit_time"])
        }
        all_cv_result.append(row)

    result_df = pd.DataFrame(all_cv_result).sort_values(
        "Mean Test Score", ascending=False
    ).reset_index(drop=True)

    return result_df

# %% [markdown]
# ## **2.1 Linear Based Model**

# %% [markdown]
# **Six linear-based algorithms will be benchmarked to select the optimal baseline model** for production deployment. This evaluation ensures the chosen model effectively addresses the underlying operational inefficiencies and solves the business problem at hand.

# %%
list_linear_models = {
    "Logistic Regression": LogisticRegression(max_iter=1000, random_state=RANDOM_STATE),
    "Ridge Classifier": RidgeClassifier(random_state=RANDOM_STATE),
    "Linear SVM (LinearSVC)": LinearSVC(dual="auto", max_iter=5000, random_state=RANDOM_STATE),
    # "Linear SVM (SVC Linear)": SVC(kernel="linear", random_state=RANDOM_STATE),
    "SGD Classifier": SGDClassifier(random_state=RANDOM_STATE),
    "Bagged Logistic Regression": BaggingClassifier(
        estimator=LogisticRegression(max_iter=1000, random_state=RANDOM_STATE),
        random_state=RANDOM_STATE
    )
}

linear_select = SelectKBest(f_classif, k=20)

linear_benchmark_selected = benchmark_models(
    pipeline=pipeline,
    list_model=list_linear_models,
    x_train=X_train, y_train=y_train,
    cv=5, random_state=RANDOM_STATE,
    scoring="average_precision",
    select=linear_select,
)

display(linear_benchmark_selected)
# Out:
#                         Model  Mean Train Score  Std Train Score  \
# 0      Linear SVM (LinearSVC)          0.187517         0.007592
# 1            Ridge Classifier          0.187666         0.007489
# 2  Bagged Logistic Regression          0.186320         0.007612
# 3         Logistic Regression          0.186386         0.007519
# 4              SGD Classifier          0.170487         0.010601
#
#    Mean Test Score  Std Test Score  Precision    Recall  F1-Score   ROC-AUC  \
# 0         0.172527        0.012469   0.116952  0.657739  0.198521  0.708012
# 1         0.172501        0.012424   0.116922  0.656787  0.198436  0.707890
# 2         0.171932        0.012249   0.118028  0.657549  0.200068  0.708178
# 3         0.171902        0.012060   0.117440  0.658730  0.199265  0.708210
# 4         0.156698        0.013369   0.117256  0.649894  0.198283  0.704377
#
#      PR-AUC  Fit Time (s)
# 0  0.172527      0.238658
# 1  0.172501      0.217637
# 2  0.171932      0.783104
# 3  0.171902      0.306357
# 4  0.156698      0.294104

# %% [markdown]
# ## **2.2 Tree Based Model**

# %% [markdown]
# **In addition to the linear approaches, seven tree-based algorithms will be evaluated** to provide a robust comparative analysis. This dual-architecture benchmarking allows us to contrast linear and non-linear patterns, ensuring the highest-performing model is selected for final deployment.

# %%
list_tree_models = {
    "Decision Tree": DecisionTreeClassifier(random_state=RANDOM_STATE),
    "Random Forest": RandomForestClassifier(random_state=RANDOM_STATE),
    "Extra Trees": ExtraTreesClassifier(random_state=RANDOM_STATE),
    "Gradient Boosting (GBM)": GradientBoostingClassifier(random_state=RANDOM_STATE),
    "AdaBoost": AdaBoostClassifier(random_state=RANDOM_STATE),
    "XGBoost": XGBClassifier(random_state=RANDOM_STATE, eval_metric="logloss"),
    "LightGBM": LGBMClassifier(random_state=RANDOM_STATE, verbose=-1)
}

tree_benchmark_selected = benchmark_models(
    pipeline=pipeline,
    list_model=list_tree_models,
    x_train=X_train, y_train=y_train,
    cv=5, random_state=RANDOM_STATE,
    scoring="average_precision"
)

display(tree_benchmark_selected)
# Out:
#                      Model  Mean Train Score  Std Train Score  \
# 0                 LightGBM          0.492122     1.483656e-01
# 1                  XGBoost          0.764849     1.406179e-01
# 2            Random Forest          0.999864     2.718701e-04
# 3  Gradient Boosting (GBM)          0.253227     2.827873e-02
# 4              Extra Trees          1.000000     9.040390e-08
# 5                 AdaBoost          0.170646     6.791016e-03
# 6            Decision Tree          1.000000     9.040390e-08
#
#    Mean Test Score  Std Test Score  Precision    Recall  F1-Score   ROC-AUC  \
# 0         0.239983        0.014929   0.495139  0.097380  0.161902  0.757401
# 1         0.222515        0.013944   0.445986  0.099118  0.161786  0.742453
# 2         0.209148        0.013949   0.417175  0.101787  0.163282  0.733233
# 3         0.197962        0.024345   0.382938  0.108957  0.168923  0.712986
# 4         0.187678        0.010581   0.354005  0.104419  0.161139  0.719610
# 5         0.153630        0.014053   0.178868  0.325442  0.218055  0.677331
# 6         0.083406        0.003444   0.155560  0.199988  0.174795  0.562169
#
#      PR-AUC  Fit Time (s)
# 0  0.239983      1.016908
# 1  0.222515      0.876130
# 2  0.209148      6.827506
# 3  0.197962     19.080545
# 4  0.187678      4.902581
# 5  0.153630      3.861438
# 6  0.083406      0.786688

# %% [markdown]
# # Section 3: Parameter Tuning

# %%
lgbm_param_rand = {
    'select': ['passthrough'],
    'smote': [
        SMOTE(random_state=RANDOM_STATE),
        SMOTEENN(random_state=RANDOM_STATE),
        SMOTETomek(random_state=RANDOM_STATE)],
    'classifier__n_estimators': [200, 400],
    'classifier__num_leaves': [7, 15],
    'classifier__max_depth': [3, 4],
    'classifier__learning_rate': [0.01, 0.05, 0.1],
    'classifier__min_child_samples': [50, 100],
    'classifier__subsample': [0.7, 0.9],
    'classifier__subsample_freq': [1],
    'classifier__colsample_bytree': [0.7, 0.9],
    'classifier__reg_lambda': [1, 5, 10],
    'classifier__reg_alpha': [0, 1],
}


tuning_pipeline = pipeline.set_params(
    classifier=LGBMClassifier(random_state=RANDOM_STATE, verbose=-1)
)

random_search = RandomizedSearchCV(
    estimator=tuning_pipeline,
    param_distributions=lgbm_param_rand,
    n_iter=50,                  
    scoring='average_precision',
    cv=TimeSeriesSplit(n_splits=5),
    n_jobs=-1,
    verbose=2,
    random_state=RANDOM_STATE
)

random_search.fit(X_train, y_train)

print("Best CV average_precision (random search):", random_search.best_score_)
print("Best params (random search):", random_search.best_params_)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.01, classifier__max_depth=3, classifier__min_child_samples=50, classifier__n_estimators=200, classifier__num_leaves=15, classifier__reg_alpha=0, classifier__reg_lambda=10, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTE(random_state=42); total time=   2.3s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.01, classifier__max_depth=3, classifier__min_child_samples=50, classifier__n_estimators=200, classifier__num_leaves=15, classifier__reg_alpha=0, classifier__reg_lambda=10, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTE(random_state=42); total time=   3.3s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.01, classifier__max_depth=3, classifier__min_child_samples=50, classifier__n_estimators=200, classifier__num_leaves=15, classifier__reg_alpha=0, classifier__reg_lambda=10, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTE(random_state=42); total time=   3.5s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.01, classifier__max_depth=3, classifier__min_child_samples=50, classifier__n_estimators=200, classifier__num_leaves=15, classifier__reg_alpha=0, classifier__reg_lambda=10, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTE(random_state=42); total time=   2.9s
# [CV] END classifier__colsample_bytree=0.9, classifier__learning_rate=0.01, classifier__max_depth=3, classifier__min_child_samples=50, classifier__n_estimators=200, classifier__num_leaves=15, classifier__reg_alpha=0, classifier__reg_lambda=5, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTETomek(random_state=42); total time=   5.7s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.01, classifier__max_depth=3, classifier__min_child_samples=50, classifier__n_estimators=200, classifier__num_leaves=15, classifier__reg_alpha=0, classifier__reg_lambda=10, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTE(random_state=42); total time=   3.3s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.01, classifier__max_depth=3, classifier__min_child_samples=100, classifier__n_estimators=200, classifier__num_leaves=15, classifier__reg_alpha=0, classifier__reg_lambda=10, classifier__subsample=0.7, classifier__subsample_freq=1, select=passthrough, smote=SMOTETomek(random_state=42); total time=   3.1s
# [CV] END classifier__colsample_bytree=0.9, classifier__learning_rate=0.01, classifier__max_depth=3, classifier__min_child_samples=50, classifier__n_estimators=200, classifier__num_leaves=15, classifier__reg_alpha=0, classifier__reg_lambda=5, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTETomek(random_state=42); total time=  10.7s
# [CV] END classifier__colsample_bytree=0.9, classifier__learning_rate=0.05, classifier__max_depth=4, classifier__min_child_samples=100, classifier__n_estimators=200, classifier__num_leaves=7, classifier__reg_alpha=1, classifier__reg_lambda=1, classifier__subsample=0.7, classifier__subsample_freq=1, select=passthrough, smote=SMOTEENN(random_state=42); total time=   3.3s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.01, classifier__max_depth=3, classifier__min_child_samples=100, classifier__n_estimators=200, classifier__num_leaves=15, classifier__reg_alpha=0, classifier__reg_lambda=10, classifier__subsample=0.7, classifier__subsample_freq=1, select=passthrough, smote=SMOTETomek(random_state=42); total time=   8.7s
# [CV] END classifier__colsample_bytree=0.9, classifier__learning_rate=0.01, classifier__max_depth=3, classifier__min_child_samples=50, classifier__n_estimators=200, classifier__num_leaves=15, classifier__reg_alpha=0, classifier__reg_lambda=5, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTETomek(random_state=42); total time=  21.2s
# [CV] END classifier__colsample_bytree=0.9, classifier__learning_rate=0.05, classifier__max_depth=4, classifier__min_child_samples=100, classifier__n_estimators=200, classifier__num_leaves=7, classifier__reg_alpha=1, classifier__reg_lambda=1, classifier__subsample=0.7, classifier__subsample_freq=1, select=passthrough, smote=SMOTEENN(random_state=42); total time=   9.6s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.01, classifier__max_depth=3, classifier__min_child_samples=100, classifier__n_estimators=200, classifier__num_leaves=15, classifier__reg_alpha=0, classifier__reg_lambda=10, classifier__subsample=0.7, classifier__subsample_freq=1, select=passthrough, smote=SMOTETomek(random_state=42); total time=  19.0s
# [CV] END classifier__colsample_bytree=0.9, classifier__learning_rate=0.01, classifier__max_depth=4, classifier__min_child_samples=50, classifier__n_estimators=200, classifier__num_leaves=7, classifier__reg_alpha=0, classifier__reg_lambda=1, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTE(random_state=42); total time=   1.3s
# [CV] END classifier__colsample_bytree=0.9, classifier__learning_rate=0.01, classifier__max_depth=4, classifier__min_child_samples=50, classifier__n_estimators=200, classifier__num_leaves=7, classifier__reg_alpha=0, classifier__reg_lambda=1, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTE(random_state=42); total time=   1.9s
# [CV] END classifier__colsample_bytree=0.9, classifier__learning_rate=0.01, classifier__max_depth=4, classifier__min_child_samples=50, classifier__n_estimators=200, classifier__num_leaves=7, classifier__reg_alpha=0, classifier__reg_lambda=1, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTE(random_state=42); total time=   2.1s
# [CV] END classifier__colsample_bytree=0.9, classifier__learning_rate=0.01, classifier__max_depth=4, classifier__min_child_samples=50, classifier__n_estimators=200, classifier__num_leaves=7, classifier__reg_alpha=0, classifier__reg_lambda=1, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTE(random_state=42); total time=   2.7s
# [CV] END classifier__colsample_bytree=0.9, classifier__learning_rate=0.05, classifier__max_depth=4, classifier__min_child_samples=100, classifier__n_estimators=200, classifier__num_leaves=7, classifier__reg_alpha=1, classifier__reg_lambda=1, classifier__subsample=0.7, classifier__subsample_freq=1, select=passthrough, smote=SMOTEENN(random_state=42); total time=  19.8s
# [CV] END classifier__colsample_bytree=0.9, classifier__learning_rate=0.01, classifier__max_depth=3, classifier__min_child_samples=50, classifier__n_estimators=200, classifier__num_leaves=15, classifier__reg_alpha=0, classifier__reg_lambda=5, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTETomek(random_state=42); total time=  34.3s
# [CV] END classifier__colsample_bytree=0.9, classifier__learning_rate=0.01, classifier__max_depth=4, classifier__min_child_samples=50, classifier__n_estimators=200, classifier__num_leaves=7, classifier__reg_alpha=0, classifier__reg_lambda=1, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTE(random_state=42); total time=   4.2s
# [CV] END classifier__colsample_bytree=0.9, classifier__learning_rate=0.05, classifier__max_depth=3, classifier__min_child_samples=50, classifier__n_estimators=400, classifier__num_leaves=15, classifier__reg_alpha=1, classifier__reg_lambda=5, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTETomek(random_state=42); total time=   4.7s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.01, classifier__max_depth=3, classifier__min_child_samples=100, classifier__n_estimators=200, classifier__num_leaves=15, classifier__reg_alpha=0, classifier__reg_lambda=10, classifier__subsample=0.7, classifier__subsample_freq=1, select=passthrough, smote=SMOTETomek(random_state=42); total time=  33.6s
# [CV] END classifier__colsample_bytree=0.9, classifier__learning_rate=0.05, classifier__max_depth=3, classifier__min_child_samples=50, classifier__n_estimators=400, classifier__num_leaves=15, classifier__reg_alpha=1, classifier__reg_lambda=5, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTETomek(random_state=42); total time=  10.9s
# [CV] END classifier__colsample_bytree=0.9, classifier__learning_rate=0.01, classifier__max_depth=4, classifier__min_child_samples=50, classifier__n_estimators=400, classifier__num_leaves=15, classifier__reg_alpha=0, classifier__reg_lambda=10, classifier__subsample=0.7, classifier__subsample_freq=1, select=passthrough, smote=SMOTETomek(random_state=42); total time=   4.8s
# [CV] END classifier__colsample_bytree=0.9, classifier__learning_rate=0.01, classifier__max_depth=3, classifier__min_child_samples=50, classifier__n_estimators=200, classifier__num_leaves=15, classifier__reg_alpha=0, classifier__reg_lambda=5, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTETomek(random_state=42); total time=  54.2s
# [CV] END classifier__colsample_bytree=0.9, classifier__learning_rate=0.05, classifier__max_depth=4, classifier__min_child_samples=100, classifier__n_estimators=200, classifier__num_leaves=7, classifier__reg_alpha=1, classifier__reg_lambda=1, classifier__subsample=0.7, classifier__subsample_freq=1, select=passthrough, smote=SMOTEENN(random_state=42); total time=  34.8s
# [CV] END classifier__colsample_bytree=0.9, classifier__learning_rate=0.05, classifier__max_depth=3, classifier__min_child_samples=50, classifier__n_estimators=400, classifier__num_leaves=15, classifier__reg_alpha=1, classifier__reg_lambda=5, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTETomek(random_state=42); total time=  21.5s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.01, classifier__max_depth=3, classifier__min_child_samples=100, classifier__n_estimators=200, classifier__num_leaves=15, classifier__reg_alpha=0, classifier__reg_lambda=10, classifier__subsample=0.7, classifier__subsample_freq=1, select=passthrough, smote=SMOTETomek(random_state=42); total time=  52.4s
# [CV] END classifier__colsample_bytree=0.9, classifier__learning_rate=0.01, classifier__max_depth=4, classifier__min_child_samples=50, classifier__n_estimators=400, classifier__num_leaves=15, classifier__reg_alpha=0, classifier__reg_lambda=10, classifier__subsample=0.7, classifier__subsample_freq=1, select=passthrough, smote=SMOTETomek(random_state=42); total time=  11.9s
# [CV] END classifier__colsample_bytree=0.9, classifier__learning_rate=0.05, classifier__max_depth=3, classifier__min_child_samples=50, classifier__n_estimators=400, classifier__num_leaves=7, classifier__reg_alpha=1, classifier__reg_lambda=10, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTETomek(random_state=42); total time=   4.4s
# [CV] END classifier__colsample_bytree=0.9, classifier__learning_rate=0.05, classifier__max_depth=3, classifier__min_child_samples=50, classifier__n_estimators=400, classifier__num_leaves=7, classifier__reg_alpha=1, classifier__reg_lambda=10, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTETomek(random_state=42); total time=  11.7s
# [CV] END classifier__colsample_bytree=0.9, classifier__learning_rate=0.05, classifier__max_depth=3, classifier__min_child_samples=50, classifier__n_estimators=400, classifier__num_leaves=15, classifier__reg_alpha=1, classifier__reg_lambda=5, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTETomek(random_state=42); total time=  37.2s
# [CV] END classifier__colsample_bytree=0.9, classifier__learning_rate=0.05, classifier__max_depth=4, classifier__min_child_samples=100, classifier__n_estimators=200, classifier__num_leaves=7, classifier__reg_alpha=1, classifier__reg_lambda=1, classifier__subsample=0.7, classifier__subsample_freq=1, select=passthrough, smote=SMOTEENN(random_state=42); total time=  53.5s
# [CV] END classifier__colsample_bytree=0.9, classifier__learning_rate=0.01, classifier__max_depth=4, classifier__min_child_samples=50, classifier__n_estimators=400, classifier__num_leaves=15, classifier__reg_alpha=0, classifier__reg_lambda=10, classifier__subsample=0.7, classifier__subsample_freq=1, select=passthrough, smote=SMOTETomek(random_state=42); total time=  23.9s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.05, classifier__max_depth=4, classifier__min_child_samples=50, classifier__n_estimators=200, classifier__num_leaves=15, classifier__reg_alpha=1, classifier__reg_lambda=5, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTE(random_state=42); total time=   1.7s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.05, classifier__max_depth=4, classifier__min_child_samples=50, classifier__n_estimators=200, classifier__num_leaves=15, classifier__reg_alpha=1, classifier__reg_lambda=5, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTE(random_state=42); total time=   2.2s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.05, classifier__max_depth=4, classifier__min_child_samples=50, classifier__n_estimators=200, classifier__num_leaves=15, classifier__reg_alpha=1, classifier__reg_lambda=5, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTE(random_state=42); total time=   2.8s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.05, classifier__max_depth=4, classifier__min_child_samples=50, classifier__n_estimators=200, classifier__num_leaves=15, classifier__reg_alpha=1, classifier__reg_lambda=5, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTE(random_state=42); total time=   3.4s
# [CV] END classifier__colsample_bytree=0.9, classifier__learning_rate=0.05, classifier__max_depth=3, classifier__min_child_samples=50, classifier__n_estimators=400, classifier__num_leaves=7, classifier__reg_alpha=1, classifier__reg_lambda=10, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTETomek(random_state=42); total time=  22.1s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.05, classifier__max_depth=4, classifier__min_child_samples=50, classifier__n_estimators=200, classifier__num_leaves=15, classifier__reg_alpha=1, classifier__reg_lambda=5, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTE(random_state=42); total time=   4.6s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.01, classifier__max_depth=4, classifier__min_child_samples=50, classifier__n_estimators=200, classifier__num_leaves=15, classifier__reg_alpha=1, classifier__reg_lambda=10, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTEENN(random_state=42); total time=   3.8s
# [CV] END classifier__colsample_bytree=0.9, classifier__learning_rate=0.01, classifier__max_depth=4, classifier__min_child_samples=50, classifier__n_estimators=400, classifier__num_leaves=15, classifier__reg_alpha=0, classifier__reg_lambda=10, classifier__subsample=0.7, classifier__subsample_freq=1, select=passthrough, smote=SMOTETomek(random_state=42); total time=  36.9s
# [CV] END classifier__colsample_bytree=0.9, classifier__learning_rate=0.05, classifier__max_depth=3, classifier__min_child_samples=50, classifier__n_estimators=400, classifier__num_leaves=15, classifier__reg_alpha=1, classifier__reg_lambda=5, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTETomek(random_state=42); total time=  54.8s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.01, classifier__max_depth=4, classifier__min_child_samples=50, classifier__n_estimators=200, classifier__num_leaves=15, classifier__reg_alpha=1, classifier__reg_lambda=10, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTEENN(random_state=42); total time=  12.6s
# [CV] END classifier__colsample_bytree=0.9, classifier__learning_rate=0.1, classifier__max_depth=3, classifier__min_child_samples=50, classifier__n_estimators=400, classifier__num_leaves=15, classifier__reg_alpha=1, classifier__reg_lambda=10, classifier__subsample=0.7, classifier__subsample_freq=1, select=passthrough, smote=SMOTE(random_state=42); total time=   3.3s
# [CV] END classifier__colsample_bytree=0.9, classifier__learning_rate=0.1, classifier__max_depth=3, classifier__min_child_samples=50, classifier__n_estimators=400, classifier__num_leaves=15, classifier__reg_alpha=1, classifier__reg_lambda=10, classifier__subsample=0.7, classifier__subsample_freq=1, select=passthrough, smote=SMOTE(random_state=42); total time=   4.0s
# [CV] END classifier__colsample_bytree=0.9, classifier__learning_rate=0.1, classifier__max_depth=3, classifier__min_child_samples=50, classifier__n_estimators=400, classifier__num_leaves=15, classifier__reg_alpha=1, classifier__reg_lambda=10, classifier__subsample=0.7, classifier__subsample_freq=1, select=passthrough, smote=SMOTE(random_state=42); total time=   4.4s
# [CV] END classifier__colsample_bytree=0.9, classifier__learning_rate=0.1, classifier__max_depth=3, classifier__min_child_samples=50, classifier__n_estimators=400, classifier__num_leaves=15, classifier__reg_alpha=1, classifier__reg_lambda=10, classifier__subsample=0.7, classifier__subsample_freq=1, select=passthrough, smote=SMOTE(random_state=42); total time=   4.5s
# [CV] END classifier__colsample_bytree=0.9, classifier__learning_rate=0.1, classifier__max_depth=3, classifier__min_child_samples=50, classifier__n_estimators=400, classifier__num_leaves=15, classifier__reg_alpha=1, classifier__reg_lambda=10, classifier__subsample=0.7, classifier__subsample_freq=1, select=passthrough, smote=SMOTE(random_state=42); total time=   5.3s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.1, classifier__max_depth=4, classifier__min_child_samples=100, classifier__n_estimators=400, classifier__num_leaves=7, classifier__reg_alpha=0, classifier__reg_lambda=1, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTEENN(random_state=42); total time=   5.0s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.01, classifier__max_depth=4, classifier__min_child_samples=50, classifier__n_estimators=200, classifier__num_leaves=15, classifier__reg_alpha=1, classifier__reg_lambda=10, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTEENN(random_state=42); total time=  26.9s
# [CV] END classifier__colsample_bytree=0.9, classifier__learning_rate=0.05, classifier__max_depth=3, classifier__min_child_samples=50, classifier__n_estimators=400, classifier__num_leaves=7, classifier__reg_alpha=1, classifier__reg_lambda=10, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTETomek(random_state=42); total time=  41.5s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.1, classifier__max_depth=4, classifier__min_child_samples=100, classifier__n_estimators=400, classifier__num_leaves=7, classifier__reg_alpha=0, classifier__reg_lambda=1, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTEENN(random_state=42); total time=  12.0s
# [CV] END classifier__colsample_bytree=0.9, classifier__learning_rate=0.01, classifier__max_depth=4, classifier__min_child_samples=50, classifier__n_estimators=400, classifier__num_leaves=15, classifier__reg_alpha=0, classifier__reg_lambda=10, classifier__subsample=0.7, classifier__subsample_freq=1, select=passthrough, smote=SMOTETomek(random_state=42); total time= 1.1min
# [CV] END classifier__colsample_bytree=0.9, classifier__learning_rate=0.1, classifier__max_depth=4, classifier__min_child_samples=50, classifier__n_estimators=200, classifier__num_leaves=15, classifier__reg_alpha=1, classifier__reg_lambda=1, classifier__subsample=0.7, classifier__subsample_freq=1, select=passthrough, smote=SMOTE(random_state=42); total time=   1.7s
# [CV] END classifier__colsample_bytree=0.9, classifier__learning_rate=0.1, classifier__max_depth=4, classifier__min_child_samples=50, classifier__n_estimators=200, classifier__num_leaves=15, classifier__reg_alpha=1, classifier__reg_lambda=1, classifier__subsample=0.7, classifier__subsample_freq=1, select=passthrough, smote=SMOTE(random_state=42); total time=   2.4s
# [CV] END classifier__colsample_bytree=0.9, classifier__learning_rate=0.1, classifier__max_depth=4, classifier__min_child_samples=50, classifier__n_estimators=200, classifier__num_leaves=15, classifier__reg_alpha=1, classifier__reg_lambda=1, classifier__subsample=0.7, classifier__subsample_freq=1, select=passthrough, smote=SMOTE(random_state=42); total time=   2.5s
# [CV] END classifier__colsample_bytree=0.9, classifier__learning_rate=0.1, classifier__max_depth=4, classifier__min_child_samples=50, classifier__n_estimators=200, classifier__num_leaves=15, classifier__reg_alpha=1, classifier__reg_lambda=1, classifier__subsample=0.7, classifier__subsample_freq=1, select=passthrough, smote=SMOTE(random_state=42); total time=   3.3s
# [CV] END classifier__colsample_bytree=0.9, classifier__learning_rate=0.1, classifier__max_depth=4, classifier__min_child_samples=50, classifier__n_estimators=200, classifier__num_leaves=15, classifier__reg_alpha=1, classifier__reg_lambda=1, classifier__subsample=0.7, classifier__subsample_freq=1, select=passthrough, smote=SMOTE(random_state=42); total time=   3.7s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.01, classifier__max_depth=4, classifier__min_child_samples=50, classifier__n_estimators=200, classifier__num_leaves=15, classifier__reg_alpha=1, classifier__reg_lambda=10, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTEENN(random_state=42); total time=  41.3s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.01, classifier__max_depth=3, classifier__min_child_samples=50, classifier__n_estimators=200, classifier__num_leaves=15, classifier__reg_alpha=1, classifier__reg_lambda=10, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTEENN(random_state=42); total time=   3.4s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.1, classifier__max_depth=4, classifier__min_child_samples=100, classifier__n_estimators=400, classifier__num_leaves=7, classifier__reg_alpha=0, classifier__reg_lambda=1, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTEENN(random_state=42); total time=  22.5s
# [CV] END classifier__colsample_bytree=0.9, classifier__learning_rate=0.05, classifier__max_depth=3, classifier__min_child_samples=50, classifier__n_estimators=400, classifier__num_leaves=7, classifier__reg_alpha=1, classifier__reg_lambda=10, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTETomek(random_state=42); total time= 1.0min
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.01, classifier__max_depth=3, classifier__min_child_samples=50, classifier__n_estimators=200, classifier__num_leaves=15, classifier__reg_alpha=1, classifier__reg_lambda=10, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTEENN(random_state=42); total time=  10.0s
# [CV] END classifier__colsample_bytree=0.9, classifier__learning_rate=0.01, classifier__max_depth=3, classifier__min_child_samples=50, classifier__n_estimators=400, classifier__num_leaves=7, classifier__reg_alpha=0, classifier__reg_lambda=5, classifier__subsample=0.7, classifier__subsample_freq=1, select=passthrough, smote=SMOTEENN(random_state=42); total time=   4.1s
# [CV] END classifier__colsample_bytree=0.9, classifier__learning_rate=0.01, classifier__max_depth=3, classifier__min_child_samples=50, classifier__n_estimators=400, classifier__num_leaves=7, classifier__reg_alpha=0, classifier__reg_lambda=5, classifier__subsample=0.7, classifier__subsample_freq=1, select=passthrough, smote=SMOTEENN(random_state=42); total time=  11.3s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.01, classifier__max_depth=3, classifier__min_child_samples=50, classifier__n_estimators=200, classifier__num_leaves=15, classifier__reg_alpha=1, classifier__reg_lambda=10, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTEENN(random_state=42); total time=  21.9s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.1, classifier__max_depth=4, classifier__min_child_samples=100, classifier__n_estimators=400, classifier__num_leaves=7, classifier__reg_alpha=0, classifier__reg_lambda=1, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTEENN(random_state=42); total time=  38.6s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.01, classifier__max_depth=4, classifier__min_child_samples=50, classifier__n_estimators=200, classifier__num_leaves=15, classifier__reg_alpha=1, classifier__reg_lambda=10, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTEENN(random_state=42); total time= 1.0min
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.05, classifier__max_depth=3, classifier__min_child_samples=50, classifier__n_estimators=400, classifier__num_leaves=7, classifier__reg_alpha=1, classifier__reg_lambda=10, classifier__subsample=0.7, classifier__subsample_freq=1, select=passthrough, smote=SMOTE(random_state=42); total time=   2.4s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.05, classifier__max_depth=3, classifier__min_child_samples=50, classifier__n_estimators=400, classifier__num_leaves=7, classifier__reg_alpha=1, classifier__reg_lambda=10, classifier__subsample=0.7, classifier__subsample_freq=1, select=passthrough, smote=SMOTE(random_state=42); total time=   3.2s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.05, classifier__max_depth=3, classifier__min_child_samples=50, classifier__n_estimators=400, classifier__num_leaves=7, classifier__reg_alpha=1, classifier__reg_lambda=10, classifier__subsample=0.7, classifier__subsample_freq=1, select=passthrough, smote=SMOTE(random_state=42); total time=   3.7s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.05, classifier__max_depth=3, classifier__min_child_samples=50, classifier__n_estimators=400, classifier__num_leaves=7, classifier__reg_alpha=1, classifier__reg_lambda=10, classifier__subsample=0.7, classifier__subsample_freq=1, select=passthrough, smote=SMOTE(random_state=42); total time=   4.8s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.05, classifier__max_depth=3, classifier__min_child_samples=50, classifier__n_estimators=400, classifier__num_leaves=7, classifier__reg_alpha=1, classifier__reg_lambda=10, classifier__subsample=0.7, classifier__subsample_freq=1, select=passthrough, smote=SMOTE(random_state=42); total time=   5.9s
# [CV] END classifier__colsample_bytree=0.9, classifier__learning_rate=0.01, classifier__max_depth=3, classifier__min_child_samples=50, classifier__n_estimators=400, classifier__num_leaves=7, classifier__reg_alpha=0, classifier__reg_lambda=5, classifier__subsample=0.7, classifier__subsample_freq=1, select=passthrough, smote=SMOTEENN(random_state=42); total time=  23.1s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.05, classifier__max_depth=4, classifier__min_child_samples=100, classifier__n_estimators=200, classifier__num_leaves=7, classifier__reg_alpha=1, classifier__reg_lambda=10, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTEENN(random_state=42); total time=   3.3s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.01, classifier__max_depth=3, classifier__min_child_samples=50, classifier__n_estimators=200, classifier__num_leaves=15, classifier__reg_alpha=1, classifier__reg_lambda=10, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTEENN(random_state=42); total time=  36.2s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.1, classifier__max_depth=4, classifier__min_child_samples=100, classifier__n_estimators=400, classifier__num_leaves=7, classifier__reg_alpha=0, classifier__reg_lambda=1, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTEENN(random_state=42); total time=  57.4s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.05, classifier__max_depth=4, classifier__min_child_samples=100, classifier__n_estimators=200, classifier__num_leaves=7, classifier__reg_alpha=1, classifier__reg_lambda=10, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTEENN(random_state=42); total time=  10.3s
# [CV] END classifier__colsample_bytree=0.9, classifier__learning_rate=0.01, classifier__max_depth=4, classifier__min_child_samples=100, classifier__n_estimators=400, classifier__num_leaves=7, classifier__reg_alpha=1, classifier__reg_lambda=5, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTEENN(random_state=42); total time=   4.6s
# [CV] END classifier__colsample_bytree=0.9, classifier__learning_rate=0.01, classifier__max_depth=4, classifier__min_child_samples=100, classifier__n_estimators=400, classifier__num_leaves=7, classifier__reg_alpha=1, classifier__reg_lambda=5, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTEENN(random_state=42); total time=  11.6s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.05, classifier__max_depth=4, classifier__min_child_samples=100, classifier__n_estimators=200, classifier__num_leaves=7, classifier__reg_alpha=1, classifier__reg_lambda=10, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTEENN(random_state=42); total time=  22.2s
# [CV] END classifier__colsample_bytree=0.9, classifier__learning_rate=0.01, classifier__max_depth=3, classifier__min_child_samples=50, classifier__n_estimators=400, classifier__num_leaves=7, classifier__reg_alpha=0, classifier__reg_lambda=5, classifier__subsample=0.7, classifier__subsample_freq=1, select=passthrough, smote=SMOTEENN(random_state=42); total time=  38.5s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.01, classifier__max_depth=3, classifier__min_child_samples=50, classifier__n_estimators=200, classifier__num_leaves=15, classifier__reg_alpha=1, classifier__reg_lambda=10, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTEENN(random_state=42); total time=  56.1s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.1, classifier__max_depth=4, classifier__min_child_samples=50, classifier__n_estimators=200, classifier__num_leaves=15, classifier__reg_alpha=1, classifier__reg_lambda=10, classifier__subsample=0.7, classifier__subsample_freq=1, select=passthrough, smote=SMOTEENN(random_state=42); total time=   3.4s
# [CV] END classifier__colsample_bytree=0.9, classifier__learning_rate=0.01, classifier__max_depth=4, classifier__min_child_samples=100, classifier__n_estimators=400, classifier__num_leaves=7, classifier__reg_alpha=1, classifier__reg_lambda=5, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTEENN(random_state=42); total time=  23.4s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.1, classifier__max_depth=4, classifier__min_child_samples=50, classifier__n_estimators=200, classifier__num_leaves=15, classifier__reg_alpha=1, classifier__reg_lambda=10, classifier__subsample=0.7, classifier__subsample_freq=1, select=passthrough, smote=SMOTEENN(random_state=42); total time=  11.0s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.05, classifier__max_depth=4, classifier__min_child_samples=100, classifier__n_estimators=200, classifier__num_leaves=7, classifier__reg_alpha=1, classifier__reg_lambda=10, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTEENN(random_state=42); total time=  36.9s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.1, classifier__max_depth=3, classifier__min_child_samples=50, classifier__n_estimators=400, classifier__num_leaves=15, classifier__reg_alpha=0, classifier__reg_lambda=1, classifier__subsample=0.7, classifier__subsample_freq=1, select=passthrough, smote=SMOTEENN(random_state=42); total time=   4.3s
# [CV] END classifier__colsample_bytree=0.9, classifier__learning_rate=0.01, classifier__max_depth=3, classifier__min_child_samples=50, classifier__n_estimators=400, classifier__num_leaves=7, classifier__reg_alpha=0, classifier__reg_lambda=5, classifier__subsample=0.7, classifier__subsample_freq=1, select=passthrough, smote=SMOTEENN(random_state=42); total time=  57.7s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.1, classifier__max_depth=4, classifier__min_child_samples=50, classifier__n_estimators=200, classifier__num_leaves=15, classifier__reg_alpha=1, classifier__reg_lambda=10, classifier__subsample=0.7, classifier__subsample_freq=1, select=passthrough, smote=SMOTEENN(random_state=42); total time=  21.5s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.1, classifier__max_depth=3, classifier__min_child_samples=50, classifier__n_estimators=400, classifier__num_leaves=15, classifier__reg_alpha=0, classifier__reg_lambda=1, classifier__subsample=0.7, classifier__subsample_freq=1, select=passthrough, smote=SMOTEENN(random_state=42); total time=  11.0s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.05, classifier__max_depth=4, classifier__min_child_samples=100, classifier__n_estimators=200, classifier__num_leaves=7, classifier__reg_alpha=1, classifier__reg_lambda=10, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTEENN(random_state=42); total time=  56.8s
# [CV] END classifier__colsample_bytree=0.9, classifier__learning_rate=0.01, classifier__max_depth=4, classifier__min_child_samples=100, classifier__n_estimators=400, classifier__num_leaves=7, classifier__reg_alpha=1, classifier__reg_lambda=5, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTEENN(random_state=42); total time=  38.6s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.01, classifier__max_depth=3, classifier__min_child_samples=50, classifier__n_estimators=400, classifier__num_leaves=15, classifier__reg_alpha=1, classifier__reg_lambda=5, classifier__subsample=0.7, classifier__subsample_freq=1, select=passthrough, smote=SMOTETomek(random_state=42); total time=   4.2s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.1, classifier__max_depth=3, classifier__min_child_samples=50, classifier__n_estimators=400, classifier__num_leaves=15, classifier__reg_alpha=0, classifier__reg_lambda=1, classifier__subsample=0.7, classifier__subsample_freq=1, select=passthrough, smote=SMOTEENN(random_state=42); total time=  22.0s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.01, classifier__max_depth=3, classifier__min_child_samples=50, classifier__n_estimators=400, classifier__num_leaves=15, classifier__reg_alpha=1, classifier__reg_lambda=5, classifier__subsample=0.7, classifier__subsample_freq=1, select=passthrough, smote=SMOTETomek(random_state=42); total time=  11.8s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.1, classifier__max_depth=4, classifier__min_child_samples=50, classifier__n_estimators=200, classifier__num_leaves=15, classifier__reg_alpha=1, classifier__reg_lambda=10, classifier__subsample=0.7, classifier__subsample_freq=1, select=passthrough, smote=SMOTEENN(random_state=42); total time=  37.2s
# [CV] END classifier__colsample_bytree=0.9, classifier__learning_rate=0.1, classifier__max_depth=4, classifier__min_child_samples=100, classifier__n_estimators=200, classifier__num_leaves=7, classifier__reg_alpha=1, classifier__reg_lambda=1, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTEENN(random_state=42); total time=   4.1s
# [CV] END classifier__colsample_bytree=0.9, classifier__learning_rate=0.01, classifier__max_depth=4, classifier__min_child_samples=100, classifier__n_estimators=400, classifier__num_leaves=7, classifier__reg_alpha=1, classifier__reg_lambda=5, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTEENN(random_state=42); total time=  57.5s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.1, classifier__max_depth=3, classifier__min_child_samples=50, classifier__n_estimators=400, classifier__num_leaves=15, classifier__reg_alpha=0, classifier__reg_lambda=1, classifier__subsample=0.7, classifier__subsample_freq=1, select=passthrough, smote=SMOTEENN(random_state=42); total time=  38.7s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.01, classifier__max_depth=3, classifier__min_child_samples=50, classifier__n_estimators=400, classifier__num_leaves=15, classifier__reg_alpha=1, classifier__reg_lambda=5, classifier__subsample=0.7, classifier__subsample_freq=1, select=passthrough, smote=SMOTETomek(random_state=42); total time=  23.8s
# [CV] END classifier__colsample_bytree=0.9, classifier__learning_rate=0.1, classifier__max_depth=4, classifier__min_child_samples=100, classifier__n_estimators=200, classifier__num_leaves=7, classifier__reg_alpha=1, classifier__reg_lambda=1, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTEENN(random_state=42); total time=  10.6s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.01, classifier__max_depth=3, classifier__min_child_samples=100, classifier__n_estimators=200, classifier__num_leaves=15, classifier__reg_alpha=1, classifier__reg_lambda=1, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTETomek(random_state=42); total time=   3.6s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.1, classifier__max_depth=4, classifier__min_child_samples=50, classifier__n_estimators=200, classifier__num_leaves=15, classifier__reg_alpha=1, classifier__reg_lambda=10, classifier__subsample=0.7, classifier__subsample_freq=1, select=passthrough, smote=SMOTEENN(random_state=42); total time=  56.2s
# [CV] END classifier__colsample_bytree=0.9, classifier__learning_rate=0.1, classifier__max_depth=4, classifier__min_child_samples=100, classifier__n_estimators=200, classifier__num_leaves=7, classifier__reg_alpha=1, classifier__reg_lambda=1, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTEENN(random_state=42); total time=  21.3s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.01, classifier__max_depth=3, classifier__min_child_samples=100, classifier__n_estimators=200, classifier__num_leaves=15, classifier__reg_alpha=1, classifier__reg_lambda=1, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTETomek(random_state=42); total time=  10.6s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.01, classifier__max_depth=3, classifier__min_child_samples=50, classifier__n_estimators=400, classifier__num_leaves=15, classifier__reg_alpha=1, classifier__reg_lambda=5, classifier__subsample=0.7, classifier__subsample_freq=1, select=passthrough, smote=SMOTETomek(random_state=42); total time=  38.3s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.05, classifier__max_depth=4, classifier__min_child_samples=50, classifier__n_estimators=400, classifier__num_leaves=7, classifier__reg_alpha=1, classifier__reg_lambda=10, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTE(random_state=42); total time=   2.1s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.05, classifier__max_depth=4, classifier__min_child_samples=50, classifier__n_estimators=400, classifier__num_leaves=7, classifier__reg_alpha=1, classifier__reg_lambda=10, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTE(random_state=42); total time=   3.5s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.1, classifier__max_depth=3, classifier__min_child_samples=50, classifier__n_estimators=400, classifier__num_leaves=15, classifier__reg_alpha=0, classifier__reg_lambda=1, classifier__subsample=0.7, classifier__subsample_freq=1, select=passthrough, smote=SMOTEENN(random_state=42); total time=  58.1s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.05, classifier__max_depth=4, classifier__min_child_samples=50, classifier__n_estimators=400, classifier__num_leaves=7, classifier__reg_alpha=1, classifier__reg_lambda=10, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTE(random_state=42); total time=   4.4s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.01, classifier__max_depth=3, classifier__min_child_samples=100, classifier__n_estimators=200, classifier__num_leaves=15, classifier__reg_alpha=1, classifier__reg_lambda=1, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTETomek(random_state=42); total time=  22.2s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.05, classifier__max_depth=4, classifier__min_child_samples=50, classifier__n_estimators=400, classifier__num_leaves=7, classifier__reg_alpha=1, classifier__reg_lambda=10, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTE(random_state=42); total time=   5.1s
# [CV] END classifier__colsample_bytree=0.9, classifier__learning_rate=0.1, classifier__max_depth=3, classifier__min_child_samples=100, classifier__n_estimators=200, classifier__num_leaves=15, classifier__reg_alpha=0, classifier__reg_lambda=10, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTETomek(random_state=42); total time=   3.6s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.05, classifier__max_depth=4, classifier__min_child_samples=50, classifier__n_estimators=400, classifier__num_leaves=7, classifier__reg_alpha=1, classifier__reg_lambda=10, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTE(random_state=42); total time=   5.3s
# [CV] END classifier__colsample_bytree=0.9, classifier__learning_rate=0.1, classifier__max_depth=4, classifier__min_child_samples=100, classifier__n_estimators=200, classifier__num_leaves=7, classifier__reg_alpha=1, classifier__reg_lambda=1, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTEENN(random_state=42); total time=  36.3s
# [CV] END classifier__colsample_bytree=0.9, classifier__learning_rate=0.1, classifier__max_depth=3, classifier__min_child_samples=100, classifier__n_estimators=200, classifier__num_leaves=15, classifier__reg_alpha=0, classifier__reg_lambda=10, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTETomek(random_state=42); total time=  10.3s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.01, classifier__max_depth=3, classifier__min_child_samples=50, classifier__n_estimators=200, classifier__num_leaves=7, classifier__reg_alpha=1, classifier__reg_lambda=10, classifier__subsample=0.7, classifier__subsample_freq=1, select=passthrough, smote=SMOTETomek(random_state=42); total time=   3.4s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.01, classifier__max_depth=3, classifier__min_child_samples=50, classifier__n_estimators=400, classifier__num_leaves=15, classifier__reg_alpha=1, classifier__reg_lambda=5, classifier__subsample=0.7, classifier__subsample_freq=1, select=passthrough, smote=SMOTETomek(random_state=42); total time=  58.8s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.01, classifier__max_depth=3, classifier__min_child_samples=100, classifier__n_estimators=200, classifier__num_leaves=15, classifier__reg_alpha=1, classifier__reg_lambda=1, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTETomek(random_state=42); total time=  37.4s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.01, classifier__max_depth=3, classifier__min_child_samples=50, classifier__n_estimators=200, classifier__num_leaves=7, classifier__reg_alpha=1, classifier__reg_lambda=10, classifier__subsample=0.7, classifier__subsample_freq=1, select=passthrough, smote=SMOTETomek(random_state=42); total time=  11.8s
# [CV] END classifier__colsample_bytree=0.9, classifier__learning_rate=0.1, classifier__max_depth=3, classifier__min_child_samples=100, classifier__n_estimators=200, classifier__num_leaves=15, classifier__reg_alpha=0, classifier__reg_lambda=10, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTETomek(random_state=42); total time=  22.7s
# [CV] END classifier__colsample_bytree=0.9, classifier__learning_rate=0.1, classifier__max_depth=4, classifier__min_child_samples=100, classifier__n_estimators=200, classifier__num_leaves=7, classifier__reg_alpha=1, classifier__reg_lambda=1, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTEENN(random_state=42); total time=  57.2s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.05, classifier__max_depth=3, classifier__min_child_samples=100, classifier__n_estimators=200, classifier__num_leaves=15, classifier__reg_alpha=1, classifier__reg_lambda=5, classifier__subsample=0.7, classifier__subsample_freq=1, select=passthrough, smote=SMOTEENN(random_state=42); total time= 2.0min
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.01, classifier__max_depth=3, classifier__min_child_samples=50, classifier__n_estimators=200, classifier__num_leaves=7, classifier__reg_alpha=1, classifier__reg_lambda=10, classifier__subsample=0.7, classifier__subsample_freq=1, select=passthrough, smote=SMOTETomek(random_state=42); total time= 2.3min
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.05, classifier__max_depth=3, classifier__min_child_samples=100, classifier__n_estimators=200, classifier__num_leaves=15, classifier__reg_alpha=1, classifier__reg_lambda=5, classifier__subsample=0.7, classifier__subsample_freq=1, select=passthrough, smote=SMOTEENN(random_state=42); total time= 2.1min
# [CV] END classifier__colsample_bytree=0.9, classifier__learning_rate=0.1, classifier__max_depth=3, classifier__min_child_samples=100, classifier__n_estimators=200, classifier__num_leaves=15, classifier__reg_alpha=0, classifier__reg_lambda=10, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTETomek(random_state=42); total time= 2.6min
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.01, classifier__max_depth=3, classifier__min_child_samples=100, classifier__n_estimators=200, classifier__num_leaves=15, classifier__reg_alpha=1, classifier__reg_lambda=1, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTETomek(random_state=42); total time= 2.9min
# ...
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.05, classifier__max_depth=3, classifier__min_child_samples=100, classifier__n_estimators=200, classifier__num_leaves=7, classifier__reg_alpha=1, classifier__reg_lambda=10, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTETomek(random_state=42); total time=  10.9s
# [CV] END classifier__colsample_bytree=0.9, classifier__learning_rate=0.01, classifier__max_depth=3, classifier__min_child_samples=100, classifier__n_estimators=200, classifier__num_leaves=7, classifier__reg_alpha=0, classifier__reg_lambda=1, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTEENN(random_state=42); total time=  34.5s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.05, classifier__max_depth=4, classifier__min_child_samples=50, classifier__n_estimators=200, classifier__num_leaves=7, classifier__reg_alpha=1, classifier__reg_lambda=5, classifier__subsample=0.7, classifier__subsample_freq=1, select=passthrough, smote=SMOTEENN(random_state=42); total time=  10.6s
# [CV] END classifier__colsample_bytree=0.9, classifier__learning_rate=0.05, classifier__max_depth=4, classifier__min_child_samples=50, classifier__n_estimators=400, classifier__num_leaves=15, classifier__reg_alpha=1, classifier__reg_lambda=5, classifier__subsample=0.7, classifier__subsample_freq=1, select=passthrough, smote=SMOTEENN(random_state=42); total time=  58.8s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.05, classifier__max_depth=3, classifier__min_child_samples=100, classifier__n_estimators=200, classifier__num_leaves=7, classifier__reg_alpha=1, classifier__reg_lambda=10, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTETomek(random_state=42); total time=  22.9s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.1, classifier__max_depth=3, classifier__min_child_samples=100, classifier__n_estimators=200, classifier__num_leaves=15, classifier__reg_alpha=0, classifier__reg_lambda=5, classifier__subsample=0.7, classifier__subsample_freq=1, select=passthrough, smote=SMOTETomek(random_state=42); total time=   3.3s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.05, classifier__max_depth=4, classifier__min_child_samples=50, classifier__n_estimators=200, classifier__num_leaves=7, classifier__reg_alpha=1, classifier__reg_lambda=5, classifier__subsample=0.7, classifier__subsample_freq=1, select=passthrough, smote=SMOTEENN(random_state=42); total time=  22.7s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.1, classifier__max_depth=3, classifier__min_child_samples=100, classifier__n_estimators=200, classifier__num_leaves=15, classifier__reg_alpha=0, classifier__reg_lambda=5, classifier__subsample=0.7, classifier__subsample_freq=1, select=passthrough, smote=SMOTETomek(random_state=42); total time=  10.5s
# [CV] END classifier__colsample_bytree=0.9, classifier__learning_rate=0.01, classifier__max_depth=3, classifier__min_child_samples=100, classifier__n_estimators=200, classifier__num_leaves=7, classifier__reg_alpha=0, classifier__reg_lambda=1, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTEENN(random_state=42); total time=  54.9s
# [CV] END classifier__colsample_bytree=0.9, classifier__learning_rate=0.05, classifier__max_depth=4, classifier__min_child_samples=50, classifier__n_estimators=400, classifier__num_leaves=7, classifier__reg_alpha=1, classifier__reg_lambda=5, classifier__subsample=0.7, classifier__subsample_freq=1, select=passthrough, smote=SMOTE(random_state=42); total time=   2.5s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.05, classifier__max_depth=3, classifier__min_child_samples=100, classifier__n_estimators=200, classifier__num_leaves=7, classifier__reg_alpha=1, classifier__reg_lambda=10, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTETomek(random_state=42); total time=  38.2s
# [CV] END classifier__colsample_bytree=0.9, classifier__learning_rate=0.05, classifier__max_depth=4, classifier__min_child_samples=50, classifier__n_estimators=400, classifier__num_leaves=7, classifier__reg_alpha=1, classifier__reg_lambda=5, classifier__subsample=0.7, classifier__subsample_freq=1, select=passthrough, smote=SMOTE(random_state=42); total time=   3.6s
# [CV] END classifier__colsample_bytree=0.9, classifier__learning_rate=0.05, classifier__max_depth=4, classifier__min_child_samples=50, classifier__n_estimators=400, classifier__num_leaves=7, classifier__reg_alpha=1, classifier__reg_lambda=5, classifier__subsample=0.7, classifier__subsample_freq=1, select=passthrough, smote=SMOTE(random_state=42); total time=   4.1s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.1, classifier__max_depth=3, classifier__min_child_samples=100, classifier__n_estimators=200, classifier__num_leaves=15, classifier__reg_alpha=0, classifier__reg_lambda=5, classifier__subsample=0.7, classifier__subsample_freq=1, select=passthrough, smote=SMOTETomek(random_state=42); total time=  21.7s
# [CV] END classifier__colsample_bytree=0.9, classifier__learning_rate=0.05, classifier__max_depth=4, classifier__min_child_samples=50, classifier__n_estimators=400, classifier__num_leaves=7, classifier__reg_alpha=1, classifier__reg_lambda=5, classifier__subsample=0.7, classifier__subsample_freq=1, select=passthrough, smote=SMOTE(random_state=42); total time=   5.1s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.1, classifier__max_depth=3, classifier__min_child_samples=100, classifier__n_estimators=400, classifier__num_leaves=7, classifier__reg_alpha=0, classifier__reg_lambda=5, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTE(random_state=42); total time=   2.6s
# [CV] END classifier__colsample_bytree=0.9, classifier__learning_rate=0.05, classifier__max_depth=4, classifier__min_child_samples=50, classifier__n_estimators=400, classifier__num_leaves=7, classifier__reg_alpha=1, classifier__reg_lambda=5, classifier__subsample=0.7, classifier__subsample_freq=1, select=passthrough, smote=SMOTE(random_state=42); total time=   5.9s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.1, classifier__max_depth=3, classifier__min_child_samples=100, classifier__n_estimators=400, classifier__num_leaves=7, classifier__reg_alpha=0, classifier__reg_lambda=5, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTE(random_state=42); total time=   3.8s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.05, classifier__max_depth=4, classifier__min_child_samples=50, classifier__n_estimators=200, classifier__num_leaves=7, classifier__reg_alpha=1, classifier__reg_lambda=5, classifier__subsample=0.7, classifier__subsample_freq=1, select=passthrough, smote=SMOTEENN(random_state=42); total time=  38.3s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.1, classifier__max_depth=3, classifier__min_child_samples=100, classifier__n_estimators=400, classifier__num_leaves=7, classifier__reg_alpha=0, classifier__reg_lambda=5, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTE(random_state=42); total time=   5.0s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.1, classifier__max_depth=3, classifier__min_child_samples=100, classifier__n_estimators=400, classifier__num_leaves=7, classifier__reg_alpha=0, classifier__reg_lambda=5, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTE(random_state=42); total time=   4.8s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.1, classifier__max_depth=3, classifier__min_child_samples=100, classifier__n_estimators=400, classifier__num_leaves=7, classifier__reg_alpha=0, classifier__reg_lambda=5, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTE(random_state=42); total time=   5.5s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.1, classifier__max_depth=4, classifier__min_child_samples=100, classifier__n_estimators=400, classifier__num_leaves=15, classifier__reg_alpha=1, classifier__reg_lambda=1, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTE(random_state=42); total time=   4.7s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.1, classifier__max_depth=4, classifier__min_child_samples=100, classifier__n_estimators=400, classifier__num_leaves=15, classifier__reg_alpha=1, classifier__reg_lambda=1, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTE(random_state=42); total time=   4.9s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.1, classifier__max_depth=4, classifier__min_child_samples=100, classifier__n_estimators=400, classifier__num_leaves=15, classifier__reg_alpha=1, classifier__reg_lambda=1, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTE(random_state=42); total time=   5.7s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.05, classifier__max_depth=3, classifier__min_child_samples=100, classifier__n_estimators=200, classifier__num_leaves=7, classifier__reg_alpha=1, classifier__reg_lambda=10, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTETomek(random_state=42); total time=  58.9s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.1, classifier__max_depth=4, classifier__min_child_samples=100, classifier__n_estimators=400, classifier__num_leaves=15, classifier__reg_alpha=1, classifier__reg_lambda=1, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTE(random_state=42); total time=   6.8s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.1, classifier__max_depth=4, classifier__min_child_samples=100, classifier__n_estimators=400, classifier__num_leaves=15, classifier__reg_alpha=1, classifier__reg_lambda=1, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTE(random_state=42); total time=   7.2s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.05, classifier__max_depth=4, classifier__min_child_samples=100, classifier__n_estimators=400, classifier__num_leaves=15, classifier__reg_alpha=0, classifier__reg_lambda=10, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTETomek(random_state=42); total time=   5.7s
# [CV] END classifier__colsample_bytree=0.9, classifier__learning_rate=0.05, classifier__max_depth=3, classifier__min_child_samples=100, classifier__n_estimators=400, classifier__num_leaves=7, classifier__reg_alpha=0, classifier__reg_lambda=10, classifier__subsample=0.7, classifier__subsample_freq=1, select=passthrough, smote=SMOTEENN(random_state=42); total time=   4.0s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.1, classifier__max_depth=3, classifier__min_child_samples=100, classifier__n_estimators=200, classifier__num_leaves=15, classifier__reg_alpha=0, classifier__reg_lambda=5, classifier__subsample=0.7, classifier__subsample_freq=1, select=passthrough, smote=SMOTETomek(random_state=42); total time=  37.8s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.05, classifier__max_depth=4, classifier__min_child_samples=100, classifier__n_estimators=400, classifier__num_leaves=15, classifier__reg_alpha=0, classifier__reg_lambda=10, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTETomek(random_state=42); total time=  12.7s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.05, classifier__max_depth=4, classifier__min_child_samples=50, classifier__n_estimators=200, classifier__num_leaves=7, classifier__reg_alpha=1, classifier__reg_lambda=5, classifier__subsample=0.7, classifier__subsample_freq=1, select=passthrough, smote=SMOTEENN(random_state=42); total time=  57.6s
# [CV] END classifier__colsample_bytree=0.9, classifier__learning_rate=0.05, classifier__max_depth=3, classifier__min_child_samples=100, classifier__n_estimators=400, classifier__num_leaves=7, classifier__reg_alpha=0, classifier__reg_lambda=10, classifier__subsample=0.7, classifier__subsample_freq=1, select=passthrough, smote=SMOTEENN(random_state=42); total time=  11.5s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.05, classifier__max_depth=4, classifier__min_child_samples=100, classifier__n_estimators=400, classifier__num_leaves=15, classifier__reg_alpha=0, classifier__reg_lambda=10, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTETomek(random_state=42); total time=  22.9s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.1, classifier__max_depth=3, classifier__min_child_samples=100, classifier__n_estimators=200, classifier__num_leaves=15, classifier__reg_alpha=0, classifier__reg_lambda=5, classifier__subsample=0.7, classifier__subsample_freq=1, select=passthrough, smote=SMOTETomek(random_state=42); total time=  56.1s
# [CV] END classifier__colsample_bytree=0.9, classifier__learning_rate=0.05, classifier__max_depth=3, classifier__min_child_samples=100, classifier__n_estimators=400, classifier__num_leaves=7, classifier__reg_alpha=0, classifier__reg_lambda=10, classifier__subsample=0.7, classifier__subsample_freq=1, select=passthrough, smote=SMOTEENN(random_state=42); total time=  21.8s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.05, classifier__max_depth=4, classifier__min_child_samples=100, classifier__n_estimators=400, classifier__num_leaves=15, classifier__reg_alpha=0, classifier__reg_lambda=10, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTETomek(random_state=42); total time=  35.8s
# [CV] END classifier__colsample_bytree=0.9, classifier__learning_rate=0.05, classifier__max_depth=3, classifier__min_child_samples=100, classifier__n_estimators=400, classifier__num_leaves=7, classifier__reg_alpha=0, classifier__reg_lambda=10, classifier__subsample=0.7, classifier__subsample_freq=1, select=passthrough, smote=SMOTEENN(random_state=42); total time=  31.3s
# [CV] END classifier__colsample_bytree=0.7, classifier__learning_rate=0.05, classifier__max_depth=4, classifier__min_child_samples=100, classifier__n_estimators=400, classifier__num_leaves=15, classifier__reg_alpha=0, classifier__reg_lambda=10, classifier__subsample=0.9, classifier__subsample_freq=1, select=passthrough, smote=SMOTETomek(random_state=42); total time=  46.1s
# [CV] END classifier__colsample_bytree=0.9, classifier__learning_rate=0.05, classifier__max_depth=3, classifier__min_child_samples=100, classifier__n_estimators=400, classifier__num_leaves=7, classifier__reg_alpha=0, classifier__reg_lambda=10, classifier__subsample=0.7, classifier__subsample_freq=1, select=passthrough, smote=SMOTEENN(random_state=42); total time=  38.5s
# Best CV average_precision (random search): 0.23928628863401474
# Best params (random search): {'smote': SMOTE(random_state=42), 'select': 'passthrough', 'classifier__subsample_freq': 1, 'classifier__subsample': 0.9, 'classifier__reg_lambda': 10, 'classifier__reg_alpha': 1, 'classifier__num_leaves': 7, 'classifier__n_estimators': 400, 'classifier__min_child_samples': 100, 'classifier__max_depth': 4, 'classifier__learning_rate': 0.1, 'classifier__colsample_bytree': 0.9}

# %%
lgbm_param_rand = {
    'select': ['passthrough'],
    'smote': [
        SMOTE(random_state=RANDOM_STATE),
        SMOTEENN(random_state=RANDOM_STATE),
        SMOTETomek(random_state=RANDOM_STATE)],
    'classifier__n_estimators': [200, 400],
    'classifier__num_leaves': [7, 15],
    'classifier__max_depth': [3, 4],
    'classifier__learning_rate': [0.01, 0.05, 0.1],
    'classifier__min_child_samples': [50, 100],
    'classifier__subsample': [0.7, 0.9],
    'classifier__subsample_freq': [1],
    'classifier__colsample_bytree': [0.7, 0.9],
    'classifier__reg_lambda': [1, 5, 10],
    'classifier__reg_alpha': [0, 1],
}


tuning_pipeline = pipeline.set_params(
    classifier=LGBMClassifier(random_state=RANDOM_STATE, verbose=-1)
)

random_search = RandomizedSearchCV(
    estimator=tuning_pipeline,
    param_distributions=lgbm_param_rand,
    n_iter=50,                  
    scoring='average_precision',
    cv=TimeSeriesSplit(n_splits=5),
    n_jobs=-1,
    verbose=1,
    random_state=9
)

random_search.fit(X_train, y_train)

print("Best CV average_precision (random search):", random_search.best_score_)
print("Best params (random search):", random_search.best_params_)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best CV average_precision (random search): 0.24211856670491963
# Best params (random search): {'smote': SMOTE(random_state=42), 'select': 'passthrough', 'classifier__subsample_freq': 1, 'classifier__subsample': 0.7, 'classifier__reg_lambda': 5, 'classifier__reg_alpha': 1, 'classifier__num_leaves': 15, 'classifier__n_estimators': 400, 'classifier__min_child_samples': 50, 'classifier__max_depth': 4, 'classifier__learning_rate': 0.1, 'classifier__colsample_bytree': 0.7}

# %%
lgbm_param_rand = {
    'select': ['passthrough'],
    'smote': [
        SMOTE(random_state=RANDOM_STATE),
        SMOTEENN(random_state=RANDOM_STATE),
        SMOTETomek(random_state=RANDOM_STATE)],
    'classifier__n_estimators': [200, 400],
    'classifier__num_leaves': [7, 15],
    'classifier__max_depth': [3, 4],
    'classifier__learning_rate': [0.01, 0.05, 0.1],
    'classifier__min_child_samples': [50, 100],
    'classifier__subsample': [0.7, 0.9],
    'classifier__subsample_freq': [1],
    'classifier__colsample_bytree': [0.7, 0.9],
    'classifier__reg_lambda': [1, 5, 10],
    'classifier__reg_alpha': [1],
}


tuning_pipeline = pipeline.set_params(
    classifier=LGBMClassifier(random_state=RANDOM_STATE, verbose=-1)
)

random_search = RandomizedSearchCV(
    estimator=tuning_pipeline,
    param_distributions=lgbm_param_rand,
    n_iter=50,                  
    scoring='average_precision',
    cv=TimeSeriesSplit(n_splits=5),
    n_jobs=-1,
    verbose=1,
    random_state=99
)

random_search.fit(X_train, y_train)

print("Best CV average_precision (random search):", random_search.best_score_)
print("Best params (random search):", random_search.best_params_)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best CV average_precision (random search): 0.23868468684805416
# Best params (random search): {'smote': SMOTETomek(random_state=42), 'select': 'passthrough', 'classifier__subsample_freq': 1, 'classifier__subsample': 0.9, 'classifier__reg_lambda': 5, 'classifier__reg_alpha': 1, 'classifier__num_leaves': 7, 'classifier__n_estimators': 400, 'classifier__min_child_samples': 100, 'classifier__max_depth': 4, 'classifier__learning_rate': 0.1, 'classifier__colsample_bytree': 0.9}

# %% [markdown]
# **Based on our baseline model benchmarking, which evaluated six linear and seven tree-based algorithms, LightGBM emerged as the top performer.** Consequently, we will perform hyperparameter tuning via Grid Search to further optimize the model's architecture and maximize predictive performance.

# %%
lgbm_param_grid = {
    'select': ['passthrough'],
    'smote': [
        SMOTE(random_state=RANDOM_STATE)],
    'classifier__n_estimators': [400],
    'classifier__num_leaves': [15],
    'classifier__max_depth': [4],
    'classifier__learning_rate': [0.1],
    'classifier__min_child_samples': [50, 100],
    'classifier__subsample': [0.7, 0.9],
    'classifier__subsample_freq': [1],
    'classifier__colsample_bytree': [0.7, 0.9],
    'classifier__reg_lambda': [1, 5],
    'classifier__reg_alpha': [0, 1],
}

tuning_pipeline = pipeline.set_params(
    classifier=LGBMClassifier(random_state=RANDOM_STATE, verbose=-1)
)

grid_search = GridSearchCV(
    estimator=tuning_pipeline,
    param_grid=lgbm_param_grid,
    scoring='average_precision',
    cv=TimeSeriesSplit(n_splits=5),
    n_jobs=-1,
    verbose=1,
)

grid_search.fit(X_train, y_train)

print("Best CV average_precision (grid search):", grid_search.best_score_)
print("Best params (grid search):", grid_search.best_params_)
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# Best CV average_precision (grid search): 0.24233946329424128
# Best params (grid search): {'classifier__colsample_bytree': 0.7, 'classifier__learning_rate': 0.1, 'classifier__max_depth': 4, 'classifier__min_child_samples': 100, 'classifier__n_estimators': 400, 'classifier__num_leaves': 15, 'classifier__reg_alpha': 0, 'classifier__reg_lambda': 5, 'classifier__subsample': 0.7, 'classifier__subsample_freq': 1, 'select': 'passthrough', 'smote': SMOTE(random_state=42)}

# %%
best_pipeline = grid_search.best_estimator_

val_proba_uncalibrated = best_pipeline.predict_proba(X_val)[:, 1]
print("Validation average_precision (uncalibrated):",
      average_precision_score(y_val, val_proba_uncalibrated))
# Out:
# Validation average_precision (uncalibrated): 0.16588829884444545

# %% [markdown]
# # Section 4: Learning Curve

# %%
calibrated_pipeline = CalibratedClassifierCV(
    estimator=FrozenEstimator(best_pipeline),
    method='isotonic'
)
calibrated_pipeline.fit(X_val, y_val)
# Out:
# CalibratedClassifierCV(estimator=FrozenEstimator(estimator=Pipeline(steps=[('feature_fix',
#                                                                             'passthrough'),
#                                                                            ('preprocessor',
#                                                                             ColumnTransformer(transformers=[('im_num',
#                                                                                                              Pipeline(steps=[('impute',
#                                                                                                                               SimpleImputer(strategy='median')),
#                                                                                                                              ('scale',
#                                                                                                                               RobustScaler())]),
#                                                                                                              ['total_weight_g',
#                                                                                                               'total_volume_cm3']),
#                                                                                                             ('im_cat',
#                                                                                                              Pipeline(steps=[('impute',
#                                                                                                                               SimpleImputer(fill_value=...
#                                                                                                                                                   func=<function convert_bool_to_int at 0x11fe47c40>))]),
#                                                                                                              ['is_interstate',
#                                                                                                               'is_black_friday_or_holiday'])])),
#                                                                            ('select',
#                                                                             'passthrough'),
#                                                                            ('smote',
#                                                                             SMOTE(random_state=42)),
#                                                                            ('classifier',
#                                                                             LGBMClassifier(colsample_bytree=0.7,
#                                                                                            max_depth=4,
#                                                                                            min_child_samples=100,
#                                                                                            n_estimators=400,
#                                                                                            num_leaves=15,
#                                                                                            random_state=42,
#                                                                                            reg_alpha=0,
#                                                                                            reg_lambda=5,
#                                                                                            subsample=0.7,
#                                                                                            subsample_freq=1,
#                                                                                            verbose=-1))])),
#                        method='isotonic')

# %%
train_sizes, train_scores, val_scores = learning_curve(
    estimator=best_pipeline,
    X=X_train, y=y_train,
    cv=TimeSeriesSplit(n_splits=5),
    scoring='average_precision',
    train_sizes=np.linspace(0.1, 1.0, 10),
    shuffle=False,           
    n_jobs=-1,
    random_state=RANDOM_STATE,
    error_score=np.nan
)

train_mean, train_std = np.nanmean(train_scores, axis=1), np.nanstd(train_scores, axis=1)
val_mean, val_std = np.nanmean(val_scores, axis=1), np.nanstd(val_scores, axis=1)

plt.figure(figsize=(8, 5))
plt.plot(train_sizes, train_mean, 'o-', color='#1f77b4', label='Training score')
plt.fill_between(train_sizes, train_mean - train_std, train_mean + train_std, alpha=0.15, color='#1f77b4')

plt.plot(train_sizes, val_mean, 'o-', color='#d62728', label='Validation score (CV)')
plt.fill_between(train_sizes, val_mean - val_std, val_mean + val_std, alpha=0.15, color='#d62728')

plt.xlabel('Training examples')
plt.ylabel('Average precision')
plt.title('Learning Curve: is the model data-limited?')
plt.legend(loc='best')
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# Based on the learning curve result, the graph is showing the overfitting pattern. The gap is very large at the beginning, around 0.83, and gradually decreases. However, the gap get smaller at the end. Since the two curves do not converge, the model still has a large generalization gap.
#
# The high training score, much lower validation score, and persistent gap indicate that the model is overfitting and has limited generalization. Adding more data provides some improvement, but the benefit becomes smaller as the dataset grows. Therefore, adding more data alone may not be enough to solve the generalization issue. Other approaches, such as regularization, feature selection, feature engineering, and hyperparameter tuning, should also be considered.
#
# Therefore, we should avoid interpreting the model as a perfect late-order detector. Instead, the model is used as a prioritization tool to identify orders with relatively higher risk, which supports our targeted intervention strategy.

# %% [markdown]
# # Section 5: Threshold Optimization

# %% [markdown]
# **Aligned with the objectives defined in the Business Understanding section, our primary goal is to maximize recall while optimizing precision** to mitigate the operational cost of excessive false alarms. To achieve this balance, we will perform threshold optimization to identify the ideal decision boundary that satisfies both requirements.

# %%
y_val_proba = calibrated_pipeline.predict_proba(X_val)[:, 1]

precisions, recalls, thresholds = precision_recall_curve(y_val, y_val_proba)

MIN_PRECISION = 0.13

precisions_t, recalls_t = precisions[:-1], recalls[:-1]

meets_floor = precisions_t >= MIN_PRECISION

if meets_floor.any():
    candidate_recalls = np.where(meets_floor, recalls_t, -1)
    best_idx = np.argmax(candidate_recalls)
    best_threshold = thresholds[best_idx]
    best_precision = precisions_t[best_idx]
    best_recall = recalls_t[best_idx]
    best_f1 = 2 * best_precision * best_recall / (best_precision + best_recall + 1e-9)

    print(f"Best threshold (max recall subject to precision >= {MIN_PRECISION:.2f}): {best_threshold:.3f}")
    print(f"  Precision: {best_precision:.3f}")
    print(f"  Recall:    {best_recall:.3f}")
    print(f"  F1:        {best_f1:.3f}")
else:
    print(f"No threshold reaches precision >= {MIN_PRECISION:.2f}.")
    print(f"Max achievable precision at any threshold is {precisions_t.max():.3f} -- lower MIN_PRECISION and rerun.")

plt.figure(figsize=(7, 5))
plt.plot(thresholds, precisions_t, label='Precision')
plt.plot(thresholds, recalls_t, label='Recall')
plt.axhline(MIN_PRECISION, color='gray', linestyle='--', linewidth=1, label='MIN_PRECISION floor')
if meets_floor.any():
    plt.axvline(best_threshold, color='red', linestyle=':', linewidth=1, label='Chosen threshold')
plt.xlabel('Threshold')
plt.ylabel('Score')
plt.title('Precision & Recall vs. Threshold (validation set)')
plt.legend()
plt.show()
# Out:
# Best threshold (max recall subject to precision >= 0.13): 0.076
#   Precision: 0.133
#   Recall:    0.870
#   F1:        0.230

# %% [markdown]
# **Upon determining the optimal decision threshold, we will construct confusion matrices to compare performance against the default baseline.** This comparative analysis will visually demonstrate how threshold tuning shifts the balance of true positives and false alarms, validating its alignment with our business objectives.

# %%
y_val_proba = calibrated_pipeline.predict_proba(X_val)[:, 1]
y_test_proba = calibrated_pipeline.predict_proba(X_test)[:, 1]

y_val_pred_untuned = (y_val_proba >= 0.5).astype(int)
y_test_pred_untuned = (y_test_proba >= 0.5).astype(int)

y_val_pred_tuned = (y_val_proba >= best_threshold).astype(int)
y_test_pred_tuned = (y_test_proba >= best_threshold).astype(int)

fig, axes = plt.subplots(2, 2, figsize=(12, 10))

axes_flat = axes.ravel()

cmu_val = confusion_matrix(y_val, y_val_pred_untuned)
cmu_test = confusion_matrix(y_test, y_test_pred_untuned)
cm_val = confusion_matrix(y_val, y_val_pred_tuned)
cm_test = confusion_matrix(y_test, y_test_pred_tuned)

ConfusionMatrixDisplay(cmu_val, display_labels=["not late", "is late"]).plot(
    ax=axes_flat[0], colorbar=False, cmap="Blues"
)
axes_flat[0].set_title("Confusion Matrix - Validation")

ConfusionMatrixDisplay(cmu_test, display_labels=["not late", "late"]).plot(
    ax=axes_flat[1], colorbar=False, cmap="Blues"
)
axes_flat[1].set_title("Confusion Matrix - Testing")

ConfusionMatrixDisplay(cm_val, display_labels=["not late", "is late"]).plot(
    ax=axes_flat[2], colorbar=False, cmap="Blues"
)
axes_flat[2].set_title("Tuned Confusion Matrix - Validation")

ConfusionMatrixDisplay(cm_test, display_labels=["not late", "late"]).plot(
    ax=axes_flat[3], colorbar=False, cmap="Blues"
)
axes_flat[3].set_title("Tuned Confusion Matrix - Testing")

plt.tight_layout()
plt.show()

# %% [markdown]
# Overview:
# - After using the customized threshold from 0.5 to 0.076, **the model significantly enhances the model's predictive capacity** (TP: 0 to 531) and missed actual late orders (FN: 680 to 149)
# - The business trade-off from the model led to noticeable increase in false alarms, escalating FP to 9286. Also, the numbers of correctly identified on-time orders decrease from 18430 to 9144 orders. As a result, Olist would need to intervene in a larger number of orders, including some that would have been delivered on time.
# - Despite the increase in false alarms, the customized threshold provides a more suitable balance for the business objective: identifying as many late orders as possible. Therefore, the model is better positioned as a risk-prioritization tool, where high-risk orders are flagged for targeted intervention rather than treating every order as equally risky.

# %% [markdown]
# # **Section 6: Model Explainability**

# %%
preprocessor_fitted = best_pipeline.named_steps['preprocessor']
select_fitted = best_pipeline.named_steps['select']
classifier = best_pipeline.named_steps['classifier']

X_train_preprocessed = preprocessor_fitted.transform(X_train)
X_test_preprocessed = preprocessor_fitted.transform(X_test)

try:
    all_feature_names = preprocessor_fitted.get_feature_names_out()
except Exception:
    all_feature_names = np.array([f"feature_{i}" for i in range(X_train_preprocessed.shape[1])])

all_feature_names = np.array([name.split('__', 1)[-1] for name in all_feature_names])

if select_fitted == 'passthrough':
    X_train_transformed = X_train_preprocessed
    X_test_transformed = X_test_preprocessed
    feature_names = all_feature_names
else:
    X_train_transformed = select_fitted.transform(X_train_preprocessed)
    X_test_transformed = select_fitted.transform(X_test_preprocessed)
    feature_names = all_feature_names[select_fitted.get_support()]

feature_names = np.asarray(feature_names, dtype=str)

X_train_transformed = pd.DataFrame(X_train_transformed, columns=feature_names)
X_test_transformed = pd.DataFrame(X_test_transformed, columns=feature_names)

print("Feature selection step in best_pipeline:", select_fitted)
print("Transformed feature matrix shape (post feature-selection):", X_test_transformed.shape)
# Out:
# Feature selection step in best_pipeline: passthrough
# Transformed feature matrix shape (post feature-selection): (19110, 70)

# %% [markdown]
# ## **6.1 Global feature importance (SHAP)**

# %%
rng = np.random.RandomState(RANDOM_STATE)

sample_idx = rng.choice(X_test_transformed.shape[0], size=min(2000, X_test_transformed.shape[0]), replace=False)
X_explain = X_test_transformed.iloc[sample_idx]

explainer = shap.TreeExplainer(classifier)
shap_values_array = explainer.shap_values(X_explain)

if isinstance(shap_values_array, list):
    shap_values_array = shap_values_array[1]

expected_value = explainer.expected_value
if isinstance(expected_value, (list, np.ndarray)) and np.ndim(expected_value) > 0:
    expected_value = expected_value[1] if len(expected_value) > 1 else expected_value[0]
base_values = np.full(len(X_explain), expected_value)

shap_values = shap.Explanation(
    values=shap_values_array,
    base_values=base_values,
    data=X_explain.values,
    feature_names=list(feature_names),
)
# Out:
# /Users/rafiandrianto/Desktop/Purwadhika/.venv/lib/python3.12/site-packages/shap/explainers/_tree.py:632: UserWarning: LightGBM binary classifier with TreeExplainer shap values output has changed to a list of ndarray
#   warnings.warn(

# %%
shap.plots.beeswarm(shap_values, max_display=20)

# %% [markdown]
# **This SHAP summary plot quantifies exactly how feature values influence delivery risk.** By mapping feature attribution values (SHAP values) against their respective data points, the visualization highlights the primary levers driving model predictions.
#
# ### Key Discoveries
#
# * **Promised Days (Top Predictor):** A shorter promised days tend to push predictions toward late, while longer promised days tend to push predictions toward on-time.
# * **Seller late rate:** Orders associated with sellers with a higher historical late-delivery rate tend to have positive SHAP values, pushing the prediction toward late. In contrast, sellers with lower historical late rates tend to push predictions toward on-time.
# * **total_freight_value:** The higher freight value is indicating that order's volume is also heavier or bulkier. The bigger order volume tend to be late, while the lighter order tend to be on-time.
# * **purchase_month:** several order months tend to be late (February and November), while some order months tend to be on-time (August, July, June). This may related to seasonal events, like Black Friday on November and National Carnival day on February.

# %%
shap.plots.bar(shap_values, max_display=20)

# %% [markdown]
# **This visualization ranks features by their absolute global importance, demonstrating that promised_days (+0.53) is the single most dominant driver of the delivery model's predictions.** Unlike a directional beeswarm plot, this chart calculates the mean absolute SHAP value (mean (|SHAP value|)), measuring the absolute magnitude of impact each variable exerts on the final prediction, regardless of whether it accelerates or delays the delivery.
#
# ### Analytical Takeaways
# * **Operations:** `promised_days` and `seller_late_rate` provide the clearest operational signals and can support risk-based monitoring and intervention.
# * **Capacity planning:** The presence of multiple temporal features suggests that seasonal patterns should be considered when planning logistics capacity.
# * **Risk prioritization:** The model should be used to prioritize high-risk orders, rather than interpreted as identifying one definitive cause of late delivery.

# %% [markdown]
# ## **6.2 Local explanation: a correctly-flagged late order**

# %%
test_proba_sample = classifier.predict_proba(X_explain)[:, 1]

y_test_sample = y_test.reset_index(drop=True).iloc[sample_idx].reset_index(drop=True)

true_positive_mask = (y_test_sample.values == 1) & (test_proba_sample >= best_threshold)

if true_positive_mask.any():
    local_pos = np.argmax(np.where(true_positive_mask, test_proba_sample, -1))
else:
    print("No true positive in this sample at the chosen threshold -- showing the highest-risk order instead.")
    local_pos = int(np.argmax(test_proba_sample))

print(f"Model probability for this order: {test_proba_sample[local_pos]:.3f} "
      f"(threshold: {best_threshold:.3f}) | Actual label: {'late' if y_test_sample.iloc[local_pos] == 1 else 'not late'}")

shap.plots.waterfall(shap_values[local_pos], max_display=15)
# Out:
# Model probability for this order: 0.154 (threshold: 0.076) | Actual label: late

# %% [markdown]
# This SHAP waterfall plot serves for **one single specific order**. While global metrics illustrate macro-level patterns, this local interpretation zooms into an individual transaction. The baseline expected value for a standard order is **-1.7** (𝐸[𝑓(𝑋)]), but due to this order's unique attributes, its final risk score escalated to **1.953** (𝑓(𝑥)).
#
# ### Analytical Takeaway
#
# Although the `seller_late_rate` is high and `promised_days` is short, temporal factors (such as purchase_month, purchase_hour) is significantly contribute negatively to the model's prediction.
#
# This case demonstrates that a high `seller_late_rate` or short `promised_days` does not automatically mean an order will be predicted as late. The model evaluates the combination of multiple factors, rather than applying a single rule such as “High-risk seller = late order.” This makes the model useful for risk prioritization, because the final prediction reflects the overall feature contribution for each individual order.

# %% [markdown]
# # **Section 7: Deployment**

# %% [markdown]
# ## **7.1 Saving Model and Seller Lookup Table**

# %% [markdown]
# **Finally, the complete model pipeline will be serialized using pickle, and the historical seller lateness lookup table will be exported** for production deployment. This ensures that both the preprocessing pipeline and the engineered features are fully preserved, enabling seamless integration and consistent inference when the model is served in production.

# %%
SELLER_LOOKUP_DIR = '../Dataset/Processed Data'
os.makedirs(SELLER_LOOKUP_DIR, exist_ok=True)

MODEL_LOOKUP_DIR = '../Assets/Model'
os.makedirs(MODEL_LOOKUP_DIR, exist_ok=True)

deploy_pipeline_for_export = copy.deepcopy(calibrated_pipeline)

with open(f'{MODEL_LOOKUP_DIR}/deploy_pipeline.pkl', 'wb') as f:
    pickle.dump(deploy_pipeline_for_export, f)

save_seller_lookup(seller_lookup, GLOBAL_LATE_RATE, SELLER_LOOKUP_DIR)
print(f'Saved {MODEL_LOOKUP_DIR}/deploy_pipeline.pkl and initial seller lookup snapshot')
# Out:
# Saved ../Assets/Model/deploy_pipeline.pkl and initial seller lookup snapshot

# %% [markdown]
# ## **7.2 Calling Model**

# %% [markdown]
# **The exported model will be invoked to verify its functionality and ensure production readiness.** This process utilizes a custom transformation function that references the seller lookup table during the pipeline's feature engineering stage, mapping the seller_id attribute to its corresponding historical lateness rate.

# %%
serving_pipeline = load_serving_model(
    model_path=f'{MODEL_LOOKUP_DIR}/deploy_pipeline.pkl',
    lookup_path=f'{SELLER_LOOKUP_DIR}/seller_lookup_latest.joblib',
)
serving_pipeline

# %% [markdown]
# ### Sanity check: raw, item-level rows in -> probability out

# %%
raw_sample = test_items

sanity_proba = serving_pipeline.predict_proba(raw_sample)[:, 1]
print('Serving pipeline output shape:', sanity_proba.shape)
print(sanity_proba[:10])
# Out:
# Serving pipeline output shape: (19110,)
# [0.06511057 0.03246753 0.05943152 0.1241535  0.10834299 0.10834299
#  0.08976558 0.10834299 0.10834299 0.17108554]
